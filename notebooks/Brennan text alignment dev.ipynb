# %% [markdown]
# This notebook: developing a text alignment function that lets us align tokens in raw text (which will be used to compute surprisals) with tokens in the Brennan CSV representation.

# %%
import re
import unicodedata

import pandas as pd
from tqdm.notebook import tqdm

# %%
stim_df = pd.read_csv("../data/AliceChapterOne-EEG.csv")

# %%
with open("../data/texts/alice-ch1.txt") as f:
    text_raw = f.read()
tokens_flat = text_raw.split()
# TODO maybe use nltk.tokenize.RegexpTokenizer("[\w']+|[^\w\s]+").tokenize(sent)

# %%
tokens_flat[:10]
# Out:
# ['Alice',
#  'was',
#  'beginning',
#  'to',
#  'get',
#  'very',
#  'tired',
#  'of',
#  'sitting',
#  'by']

# %%
def strip_accents(s):
    return unicodedata.normalize("NFKD", s).encode("ASCII", "ignore").decode("utf-8")

# %%
punct_re = re.compile(r"[^A-Za-z]")

def process_fulltext_token(t):
    ret = strip_accents(t.lower())
    ret = punct_re.sub("", ret)
    return ret

def align_stimulus_fulltext(stim_df, tokens_flat):
    """
    Prepare an alignment between the eperimental stimuli and the fulltext token
    indices, so that we can provide surprisal predictors.

    Adds a new column `tok_pos` to `stim_df` describing the corresponding
    position for each row in the fulltext. (inplace)
    """

    stop = False

    tok_cursor = 0
    tok_el = process_fulltext_token(tokens_flat[tok_cursor])

    # For each element in surp_df, record the index of the corresponding element
    # in the token sequence or surprisal df.
    tok_pos = []
    for _, row in tqdm(stim_df.iterrows(), total=len(stim_df)):
        if stop:
            break

        df_el = punct_re.sub("", row.Word.lower())
        print(row.Word, "::", df_el, "::")

        # Track how many elements in a reference we have skipped. If this
        # is excessive, we'll quit rather than looping infinitely.
        skip_count = 0
        if stop:
            raise RuntimeError("abort")
            break

        # Find corresponding token in text and append to `tok_pos`.
        try:
            print("\t///", tok_el, df_el)
            while not tok_el.startswith(df_el):
                # Special cases for oddities in the Brennan stim df..
                if tok_el == "is" and df_el == "s":
                    # annotation says "\x1as" which gets stripped
                    break
                elif tok_el == "had" and df_el == "d":
                    # annotation says "\x1ad" which gets stripped
                    break

                tok_cursor += 1
                skip_count += 1
                if skip_count > 20:
                    stop = True
                    break

                tok_el = process_fulltext_token(tokens_flat[tok_cursor])
                print("\t//", tok_el)

            print("\tMatch", df_el, tok_el)
            tok_pos.append(tok_cursor)

            # If we matched only a subset of the token, then cut off what we
            # matched and proceed.
            if tok_el != df_el:
                tok_el = tok_el[len(df_el):]
            else:
                tok_cursor += 1
                tok_el = process_fulltext_token(tokens_flat[tok_cursor])
        except IndexError:
            # print("iex", row, tok_cursor, tok_el)
            stop = True
            break

    stim_df["tok_pos"] = tok_pos

# %%
align_stimulus_fulltext(stim_df, tokens_flat)
# Out:
#   0%|          | 0/2129 [00:00<?, ?it/s]
# Alice :: alice ::
# 	/// alice alice
# 	Match alice alice
# was :: was ::
# 	/// was was
# 	Match was was
# beginning :: beginning ::
# 	/// beginning beginning
# 	Match beginning beginning
# to :: to ::
# 	/// to to
# 	Match to to
# get :: get ::
# 	/// get get
# 	Match get get
# very :: very ::
# 	/// very very
# 	Match very very
# tired :: tired ::
# 	/// tired tired
# 	Match tired tired
# of :: of ::
# 	/// of of
# 	Match of of
# sitting :: sitting ::
# 	/// sitting sitting
# 	Match sitting sitting
# by :: by ::
# 	/// by by
# 	Match by by
# her :: her ::
# 	/// her her
# 	Match her her
# sister :: sister ::
# 	/// sister sister
# 	Match sister sister
# on :: on ::
# 	/// on on
# 	Match on on
# the :: the ::
# 	/// the the
# 	Match the the
# bank :: bank ::
# 	/// bank bank
# 	Match bank bank
# and :: and ::
# 	/// and and
# 	Match and and
# of :: of ::
# 	/// of of
# 	Match of of
# having :: having ::
# 	/// having having
# 	Match having having
# nothing :: nothing ::
# 	/// nothing nothing
# 	Match nothing nothing
# to :: to ::
# 	/// to to
# 	Match to to
# do :: do ::
# 	/// do do
# 	Match do do
# once :: once ::
# 	/// once once
# 	Match once once
# or :: or ::
# 	/// or or
# 	Match or or
# twice :: twice ::
# 	/// twice twice
# 	Match twice twice
# she :: she ::
# 	/// she she
# 	Match she she
# peeped :: peeped ::
# 	/// had peeped
# 	// peeped
# 	Match peeped peeped
# into :: into ::
# 	/// into into
# 	Match into into
# the :: the ::
# 	/// the the
# 	Match the the
# book :: book ::
# 	/// book book
# 	Match book book
# her :: her ::
# 	/// her her
# 	Match her her
# sister :: sister ::
# 	/// sister sister
# 	Match sister sister
# was :: was ::
# 	/// was was
# 	Match was was
# reading :: reading ::
# 	/// reading reading
# 	Match reading reading
# but :: but ::
# 	/// but but
# 	Match but but
# it :: it ::
# 	/// it it
# 	Match it it
# had :: had ::
# 	/// had had
# 	Match had had
# no :: no ::
# 	/// no no
# 	Match no no
# pictures :: pictures ::
# 	/// pictures pictures
# 	Match pictures pictures
# or :: or ::
# 	/// or or
# 	Match or or
# conversations :: conversations ::
# 	/// conversations conversations
# 	Match conversations conversations
# in :: in ::
# 	/// in in
# 	Match in in
# it :: it ::
# 	/// it it
# 	Match it it
# and :: and ::
# 	/// and and
# 	Match and and
# what :: what ::
# 	/// what what
# 	Match what what
# s :: s ::
# 	/// is s
# 	Match s is
# the :: the ::
# 	/// s the
# 	// the
# 	Match the the
# use :: use ::
# 	/// use use
# 	Match use use
# of :: of ::
# 	/// of of
# 	Match of of
# a :: a ::
# 	/// a a
# 	Match a a
# book :: book ::
# 	/// book book
# 	Match book book
# thought :: thought ::
# 	/// thought thought
# 	Match thought thought
# Alice :: alice ::
# 	/// alice alice
# 	Match alice alice
# without :: without ::
# 	/// without without
# 	Match without without
# pictures :: pictures ::
# 	/// pictures pictures
# 	Match pictures pictures
# or :: or ::
# 	/// or or
# 	Match or or
# conversation :: conversation ::
# 	/// conversation conversation
# 	Match conversation conversation
# So :: so ::
# 	/// so so
# 	Match so so
# she :: she ::
# 	/// she she
# 	Match she she
# was :: was ::
# 	/// was was
# 	Match was was
# considering :: considering ::
# 	/// considering considering
# 	Match considering considering
# in :: in ::
# 	/// in in
# 	Match in in
# her :: her ::
# 	/// her her
# 	Match her her
# own :: own ::
# 	/// own own
# 	Match own own
# mind :: mind ::
# 	/// mind mind
# 	Match mind mind
# as :: as ::
# 	/// as as
# 	Match as as
# well :: well ::
# 	/// well well
# 	Match well well
# as :: as ::
# 	/// as as
# 	Match as as
# she :: she ::
# 	/// she she
# 	Match she she
# could :: could ::
# 	/// could could
# 	Match could could
# for :: for ::
# 	/// for for
# 	Match for for
# the :: the ::
# 	/// the the
# 	Match the the
# hot :: hot ::
# 	/// hot hot
# 	Match hot hot
# day :: day ::
# 	/// day day
# 	Match day day
# made :: made ::
# 	/// made made
# 	Match made made
# her :: her ::
# 	/// her her
# 	Match her her
# feel :: feel ::
# 	/// feel feel
# 	Match feel feel
# very :: very ::
# 	/// very very
# 	Match very very
# sleepy :: sleepy ::
# 	/// sleepy sleepy
# 	Match sleepy sleepy
# and :: and ::
# 	/// and and
# 	Match and and
# stupid :: stupid ::
# 	/// stupid stupid
# 	Match stupid stupid
# whether :: whether ::
# 	/// whether whether
# 	Match whether whether
# the :: the ::
# 	/// the the
# 	Match the the
# pleasure :: pleasure ::
# 	/// pleasure pleasure
# 	Match pleasure pleasure
# of :: of ::
# 	/// of of
# 	Match of of
# making :: making ::
# 	/// making making
# 	Match making making
# a :: a ::
# 	/// a a
# 	Match a a
# daisy :: daisy ::
# 	/// daisychain daisy
# 	Match daisy daisychain
# chain :: chain ::
# 	/// chain chain
# 	Match chain chain
# would :: would ::
# 	/// would would
# 	Match would would
# be :: be ::
# 	/// be be
# 	Match be be
# worth :: worth ::
# 	/// worth worth
# 	Match worth worth
# the :: the ::
# 	/// the the
# 	Match the the
# trouble :: trouble ::
# 	/// trouble trouble
# 	Match trouble trouble
# of :: of ::
# 	/// of of
# 	Match of of
# getting :: getting ::
# 	/// getting getting
# 	Match getting getting
# up :: up ::
# 	/// up up
# 	Match up up
# and :: and ::
# 	/// and and
# 	Match and and
# picking :: picking ::
# 	/// picking picking
# 	Match picking picking
# the :: the ::
# 	/// the the
# 	Match the the
# daisies :: daisies ::
# 	/// daisies daisies
# 	Match daisies daisies
# when :: when ::
# 	/// when when
# 	Match when when
# suddenly :: suddenly ::
# 	/// suddenly suddenly
# 	Match suddenly suddenly
# a :: a ::
# 	/// a a
# 	Match a a
# White :: white ::
# 	/// white white
# 	Match white white
# Rabbit :: rabbit ::
# 	/// rabbit rabbit
# 	Match rabbit rabbit
# with :: with ::
# 	/// with with
# 	Match with with
# pink :: pink ::
# 	/// pink pink
# 	Match pink pink
# eyes :: eyes ::
# 	/// eyes eyes
# 	Match eyes eyes
# ran :: ran ::
# 	/// ran ran
# 	Match ran ran
# close :: close ::
# 	/// close close
# 	Match close close
# by :: by ::
# 	/// by by
# 	Match by by
# her :: her ::
# 	/// her her
# 	Match her her
# There :: there ::
# 	/// there there
# 	Match there there
# was :: was ::
# 	/// was was
# 	Match was was
# nothing :: nothing ::
# 	/// nothing nothing
# 	Match nothing nothing
# so :: so ::
# 	/// so so
# 	Match so so
# very :: very ::
# 	/// very very
# 	Match very very
# remarkable :: remarkable ::
# 	/// remarkable remarkable
# 	Match remarkable remarkable
# in :: in ::
# 	/// in in
# 	Match in in
# that :: that ::
# 	/// that that
# 	Match that that
# nor :: nor ::
# 	/// nor nor
# 	Match nor nor
# did :: did ::
# 	/// did did
# 	Match did did
# Alice :: alice ::
# 	/// alice alice
# 	Match alice alice
# think :: think ::
# 	/// think think
# 	Match think think
# it :: it ::
# 	/// it it
# 	Match it it
# so :: so ::
# 	/// so so
# 	Match so so
# very :: very ::
# 	/// very very
# 	Match very very
# much :: much ::
# 	/// much much
# 	Match much much
# out :: out ::
# 	/// out out
# 	Match out out
# of :: of ::
# 	/// of of
# 	Match of of
# the :: the ::
# 	/// the the
# 	Match the the
# way :: way ::
# 	/// way way
# 	Match way way
# to :: to ::
# 	/// to to
# 	Match to to
# hear :: hear ::
# 	/// hear hear
# 	Match hear hear
# the :: the ::
# 	/// the the
# 	Match the the
# Rabbit :: rabbit ::
# 	/// rabbit rabbit
# 	Match rabbit rabbit
# say :: say ::
# 	/// say say
# 	Match say say
# to :: to ::
# 	/// to to
# 	Match to to
# itself :: itself ::
# 	/// itself itself
# 	Match itself itself
# Oh :: oh ::
# 	/// oh oh
# 	Match oh oh
# dear :: dear ::
# 	/// dear dear
# 	Match dear dear
# Oh :: oh ::
# 	/// oh oh
# 	Match oh oh
# dear :: dear ::
# 	/// dear dear
# 	Match dear dear
# I :: i ::
# 	/// i i
# 	Match i i
# shall :: shall ::
# 	/// shall shall
# 	Match shall shall
# be :: be ::
# 	/// be be
# 	Match be be
# late :: late ::
# 	/// late late
# 	Match late late
# when :: when ::
# 	/// when when
# 	Match when when
# she :: she ::
# 	/// she she
# 	Match she she
# thought :: thought ::
# 	/// thought thought
# 	Match thought thought
# it :: it ::
# 	/// it it
# 	Match it it
# over :: over ::
# 	/// over over
# 	Match over over
# afterwards :: afterwards ::
# 	/// afterwards afterwards
# 	Match afterwards afterwards
# it :: it ::
# 	/// it it
# 	Match it it
# occurred :: occurred ::
# 	/// occurred occurred
# 	Match occurred occurred
# to :: to ::
# 	/// to to
# 	Match to to
# her :: her ::
# 	/// her her
# 	Match her her
# that :: that ::
# 	/// that that
# 	Match that that
# she :: she ::
# 	/// she she
# 	Match she she
# ought :: ought ::
# 	/// ought ought
# 	Match ought ought
# to :: to ::
# 	/// to to
# 	Match to to
# have :: have ::
# 	/// have have
# 	Match have have
# wondered :: wondered ::
# 	/// wondered wondered
# 	Match wondered wondered
# at :: at ::
# 	/// at at
# 	Match at at
# this :: this ::
# 	/// this this
# 	Match this this
# but :: but ::
# 	/// but but
# 	Match but but
# at :: at ::
# 	/// at at
# 	Match at at
# the :: the ::
# 	/// the the
# 	Match the the
# time :: time ::
# 	/// time time
# 	Match time time
# it :: it ::
# 	/// it it
# 	Match it it
# all :: all ::
# 	/// all all
# 	Match all all
# seemed :: seemed ::
# 	/// seemed seemed
# 	Match seemed seemed
# quite :: quite ::
# 	/// quite quite
# 	Match quite quite
# natural :: natural ::
# 	/// natural natural
# 	Match natural natural
# but :: but ::
# 	/// but but
# 	Match but but
# when :: when ::
# 	/// when when
# 	Match when when
# the :: the ::
# 	/// the the
# 	Match the the
# Rabbit :: rabbit ::
# 	/// rabbit rabbit
# 	Match rabbit rabbit
# actually :: actually ::
# 	/// actually actually
# 	Match actually actually
# took :: took ::
# 	/// took took
# 	Match took took
# a :: a ::
# 	/// a a
# 	Match a a
# watch :: watch ::
# 	/// watch watch
# 	Match watch watch
# out :: out ::
# 	/// out out
# 	Match out out
# of :: of ::
# 	/// of of
# 	Match of of
# its :: its ::
# 	/// its its
# 	Match its its
# waistcoat :: waistcoat ::
# 	/// waistcoatpocket waistcoat
# 	Match waistcoat waistcoatpocket
# pocket :: pocket ::
# 	/// pocket pocket
# 	Match pocket pocket
# and :: and ::
# 	/// and and
# 	Match and and
# looked :: looked ::
# 	/// looked looked
# 	Match looked looked
# at :: at ::
# 	/// at at
# 	Match at at
# it :: it ::
# 	/// it it
# 	Match it it
# and :: and ::
# 	/// and and
# 	Match and and
# then :: then ::
# 	/// then then
# 	Match then then
# hurried :: hurried ::
# 	/// hurried hurried
# 	Match hurried hurried
# on :: on ::
# 	/// on on
# 	Match on on
# Alice :: alice ::
# 	/// alice alice
# 	Match alice alice
# started :: started ::
# 	/// started started
# 	Match started started
# to :: to ::
# 	/// to to
# 	Match to to
# her :: her ::
# 	/// her her
# 	Match her her
# feet :: feet ::
# 	/// feet feet
# 	Match feet feet
# for :: for ::
# 	/// for for
# 	Match for for
# it :: it ::
# 	/// it it
# 	Match it it
# flashed :: flashed ::
# 	/// flashed flashed
# 	Match flashed flashed
# across :: across ::
# 	/// across across
# 	Match across across
# her :: her ::
# 	/// her her
# 	Match her her
# mind :: mind ::
# 	/// mind mind
# 	Match mind mind
# that :: that ::
# 	/// that that
# 	Match that that
# she :: she ::
# 	/// she she
# 	Match she she
# d :: d ::
# 	/// had d
# 	Match d had
# never :: never ::
# 	/// ad never
# 	// never
# 	Match never never
# before :: before ::
# 	/// before before
# 	Match before before
# seen :: seen ::
# 	/// seen seen
# 	Match seen seen
# a :: a ::
# 	/// a a
# 	Match a a
# rabbit :: rabbit ::
# 	/// rabbit rabbit
# 	Match rabbit rabbit
# with :: with ::
# 	/// with with
# 	Match with with
# either :: either ::
# 	/// either either
# 	Match either either
# a :: a ::
# 	/// a a
# 	Match a a
# waistcoat :: waistcoat ::
# 	/// waistcoatpocket waistcoat
# 	Match waistcoat waistcoatpocket
# pocket :: pocket ::
# 	/// pocket pocket
# 	Match pocket pocket
# or :: or ::
# 	/// or or
# 	Match or or
# a :: a ::
# 	/// a a
# 	Match a a
# watch :: watch ::
# 	/// watch watch
# 	Match watch watch
# to :: to ::
# 	/// to to
# 	Match to to
# take :: take ::
# 	/// take take
# 	Match take take
# out :: out ::
# 	/// out out
# 	Match out out
# of :: of ::
# 	/// of of
# 	Match of of
# it :: it ::
# 	/// it it
# 	Match it it
# and :: and ::
# 	/// and and
# 	Match and and
# burning :: burning ::
# 	/// burning burning
# 	Match burning burning
# with :: with ::
# 	/// with with
# 	Match with with
# curiosity :: curiosity ::
# 	/// curiosity curiosity
# 	Match curiosity curiosity
# she :: she ::
# 	/// she she
# 	Match she she
# ran :: ran ::
# 	/// ran ran
# 	Match ran ran
# across :: across ::
# 	/// across across
# 	Match across across
# the :: the ::
# 	/// the the
# 	Match the the
# field :: field ::
# 	/// field field
# 	Match field field
# after :: after ::
# 	/// after after
# 	Match after after
# it :: it ::
# 	/// it it
# 	Match it it
# and :: and ::
# 	/// and and
# 	Match and and
# fortunately :: fortunately ::
# 	/// fortunately fortunately
# 	Match fortunately fortunately
# was :: was ::
# 	/// was was
# 	Match was was
# just :: just ::
# 	/// just just
# 	Match just just
# in :: in ::
# 	/// in in
# 	Match in in
# time :: time ::
# 	/// time time
# 	Match time time
# to :: to ::
# 	/// to to
# 	Match to to
# see :: see ::
# 	/// see see
# 	Match see see
# it :: it ::
# 	/// it it
# 	Match it it
# pop :: pop ::
# 	/// pop pop
# 	Match pop pop
# down :: down ::
# 	/// down down
# 	Match down down
# a :: a ::
# 	/// a a
# 	Match a a
# large :: large ::
# 	/// large large
# 	Match large large
# rabbit :: rabbit ::
# 	/// rabbithole rabbit
# 	Match rabbit rabbithole
# hole :: hole ::
# 	/// hole hole
# 	Match hole hole
# under :: under ::
# 	/// under under
# 	Match under under
# the :: the ::
# 	/// the the
# 	Match the the
# hedge :: hedge ::
# 	/// hedge hedge
# 	Match hedge hedge
# In :: in ::
# 	/// in in
# 	Match in in
# another :: another ::
# 	/// another another
# 	Match another another
# moment :: moment ::
# 	/// moment moment
# 	Match moment moment
# down :: down ::
# 	/// down down
# 	Match down down
# went :: went ::
# 	/// went went
# 	Match went went
# Alice :: alice ::
# 	/// alice alice
# 	Match alice alice
# after :: after ::
# 	/// after after
# 	Match after after
# it :: it ::
# 	/// it it
# 	Match it it
# never :: never ::
# 	/// never never
# 	Match never never
# once :: once ::
# 	/// once once
# 	Match once once
# considering :: considering ::
# 	/// considering considering
# 	Match considering considering
# how :: how ::
# 	/// how how
# 	Match how how
# in :: in ::
# 	/// in in
# 	Match in in
# the :: the ::
# 	/// the the
# 	Match the the
# world :: world ::
# 	/// world world
# 	Match world world
# she :: she ::
# 	/// she she
# 	Match she she
# was :: was ::
# 	/// was was
# 	Match was was
# to :: to ::
# 	/// to to
# 	Match to to
# get :: get ::
# 	/// get get
# 	Match get get
# out :: out ::
# 	/// out out
# 	Match out out
# again :: again ::
# 	/// again again
# 	Match again again
# The :: the ::
# 	/// the the
# 	Match the the
# rabbit :: rabbit ::
# 	/// rabbithole rabbit
# 	Match rabbit rabbithole
# hole :: hole ::
# 	/// hole hole
# 	Match hole hole
# went :: went ::
# 	/// went went
# 	Match went went
# straight :: straight ::
# 	/// straight straight
# 	Match straight straight
# on :: on ::
# 	/// on on
# 	Match on on
# like :: like ::
# 	/// like like
# 	Match like like
# a :: a ::
# 	/// a a
# 	Match a a
# tunnel :: tunnel ::
# 	/// tunnel tunnel
# 	Match tunnel tunnel
# for :: for ::
# 	/// for for
# 	Match for for
# some :: some ::
# 	/// some some
# 	Match some some
# way :: way ::
# 	/// way way
# 	Match way way
# and :: and ::
# 	/// and and
# 	Match and and
# then :: then ::
# 	/// then then
# 	Match then then
# dipped :: dipped ::
# 	/// dipped dipped
# 	Match dipped dipped
# suddenly :: suddenly ::
# 	/// suddenly suddenly
# 	Match suddenly suddenly
# down :: down ::
# 	/// down down
# 	Match down down
# so :: so ::
# 	/// so so
# 	Match so so
# suddenly :: suddenly ::
# 	/// suddenly suddenly
# 	Match suddenly suddenly
# that :: that ::
# 	/// that that
# 	Match that that
# Alice :: alice ::
# 	/// alice alice
# 	Match alice alice
# had :: had ::
# 	/// had had
# 	Match had had
# not :: not ::
# 	/// not not
# 	Match not not
# a :: a ::
# 	/// a a
# 	Match a a
# moment :: moment ::
# 	/// moment moment
# 	Match moment moment
# to :: to ::
# 	/// to to
# 	Match to to
# think :: think ::
# 	/// think think
# 	Match think think
# about :: about ::
# 	/// about about
# 	Match about about
# stopping :: stopping ::
# 	/// stopping stopping
# 	Match stopping stopping
# herself :: herself ::
# 	/// herself herself
# 	Match herself herself
# before :: before ::
# 	/// before before
# 	Match before before
# she :: she ::
# 	/// she she
# 	Match she she
# found :: found ::
# 	/// found found
# 	Match found found
# herself :: herself ::
# 	/// herself herself
# 	Match herself herself
# falling :: falling ::
# 	/// falling falling
# 	Match falling falling
# down :: down ::
# 	/// down down
# 	Match down down
# a :: a ::
# 	/// a a
# 	Match a a
# very :: very ::
# 	/// very very
# 	Match very very
# deep :: deep ::
# 	/// deep deep
# 	Match deep deep
# well :: well ::
# 	/// well well
# 	Match well well
# Either :: either ::
# 	/// either either
# 	Match either either
# the :: the ::
# 	/// the the
# 	Match the the
# well :: well ::
# 	/// well well
# 	Match well well
# was :: was ::
# 	/// was was
# 	Match was was
# very :: very ::
# 	/// very very
# 	Match very very
# deep :: deep ::
# 	/// deep deep
# 	Match deep deep
# or :: or ::
# 	/// or or
# 	Match or or
# she :: she ::
# 	/// she she
# 	Match she she
# fell :: fell ::
# 	/// fell fell
# 	Match fell fell
# very :: very ::
# 	/// very very
# 	Match very very
# slowly :: slowly ::
# 	/// slowly slowly
# 	Match slowly slowly
# for :: for ::
# 	/// for for
# 	Match for for
# she :: she ::
# 	/// she she
# 	Match she she
# had :: had ::
# 	/// had had
# 	Match had had
# plenty :: plenty ::
# 	/// plenty plenty
# 	Match plenty plenty
# of :: of ::
# 	/// of of
# 	Match of of
# time :: time ::
# 	/// time time
# 	Match time time
# as :: as ::
# 	/// as as
# 	Match as as
# she :: she ::
# 	/// she she
# 	Match she she
# went :: went ::
# 	/// went went
# 	Match went went
# down :: down ::
# 	/// down down
# 	Match down down
# to :: to ::
# 	/// to to
# 	Match to to
# look :: look ::
# 	/// look look
# 	Match look look
# about :: about ::
# 	/// about about
# 	Match about about
# her :: her ::
# 	/// her her
# 	Match her her
# and :: and ::
# 	/// and and
# 	Match and and
# to :: to ::
# 	/// to to
# 	Match to to
# wonder :: wonder ::
# 	/// wonder wonder
# 	Match wonder wonder
# what :: what ::
# 	/// what what
# 	Match what what
# was :: was ::
# 	/// was was
# 	Match was was
# going :: going ::
# 	/// going going
# 	Match going going
# to :: to ::
# 	/// to to
# 	Match to to
# happen :: happen ::
# 	/// happen happen
# 	Match happen happen
# next :: next ::
# 	/// next next
# 	Match next next
# First :: first ::
# 	/// first first
# 	Match first first
# she :: she ::
# 	/// she she
# 	Match she she
# tried :: tried ::
# 	/// tried tried
# 	Match tried tried
# to :: to ::
# 	/// to to
# 	Match to to
# look :: look ::
# 	/// look look
# 	Match look look
# down :: down ::
# 	/// down down
# 	Match down down
# and :: and ::
# 	/// and and
# 	Match and and
# make :: make ::
# 	/// make make
# 	Match make make
# out :: out ::
# 	/// out out
# 	Match out out
# what :: what ::
# 	/// what what
# 	Match what what
# she :: she ::
# 	/// she she
# 	Match she she
# was :: was ::
# 	/// was was
# 	Match was was
# coming :: coming ::
# 	/// coming coming
# 	Match coming coming
# to :: to ::
# 	/// to to
# 	Match to to
# but :: but ::
# 	/// but but
# 	Match but but
# it :: it ::
# 	/// it it
# 	Match it it
# was :: was ::
# 	/// was was
# 	Match was was
# too :: too ::
# 	/// too too
# 	Match too too
# dark :: dark ::
# 	/// dark dark
# 	Match dark dark
# to :: to ::
# 	/// to to
# 	Match to to
# see :: see ::
# 	/// see see
# 	Match see see
# anything :: anything ::
# 	/// anything anything
# 	Match anything anything
# then :: then ::
# 	/// then then
# 	Match then then
# she :: she ::
# 	/// she she
# 	Match she she
# looked :: looked ::
# 	/// looked looked
# 	Match looked looked
# at :: at ::
# 	/// at at
# 	Match at at
# the :: the ::
# 	/// the the
# 	Match the the
# sides :: sides ::
# 	/// sides sides
# 	Match sides sides
# of :: of ::
# 	/// of of
# 	Match of of
# the :: the ::
# 	/// the the
# 	Match the the
# well :: well ::
# 	/// well well
# 	Match well well
# and :: and ::
# 	/// and and
# 	Match and and
# noticed :: noticed ::
# 	/// noticed noticed
# 	Match noticed noticed
# that :: that ::
# 	/// that that
# 	Match that that
# they :: they ::
# 	/// they they
# 	Match they they
# were :: were ::
# 	/// were were
# 	Match were were
# filled :: filled ::
# 	/// filled filled
# 	Match filled filled
# with :: with ::
# 	/// with with
# 	Match with with
# cupboards :: cupboards ::
# 	/// cupboards cupboards
# 	Match cupboards cupboards
# and :: and ::
# 	/// and and
# 	Match and and
# bookshelves :: bookshelves ::
# 	/// bookshelves bookshelves
# 	Match bookshelves bookshelves
# here :: here ::
# 	/// here here
# 	Match here here
# and :: and ::
# 	/// and and
# 	Match and and
# there :: there ::
# 	/// there there
# 	Match there there
# she :: she ::
# 	/// she she
# 	Match she she
# saw :: saw ::
# 	/// saw saw
# 	Match saw saw
# maps :: maps ::
# 	/// maps maps
# 	Match maps maps
# and :: and ::
# 	/// and and
# 	Match and and
# pictures :: pictures ::
# 	/// pictures pictures
# 	Match pictures pictures
# hung :: hung ::
# 	/// hung hung
# 	Match hung hung
# up :: up ::
# 	/// upon up
# 	Match up upon
# on :: on ::
# 	/// on on
# 	Match on on
# pegs :: pegs ::
# 	/// pegs pegs
# 	Match pegs pegs
# She :: she ::
# 	/// she she
# 	Match she she
# took :: took ::
# 	/// took took
# 	Match took took
# down :: down ::
# 	/// down down
# 	Match down down
# a :: a ::
# 	/// a a
# 	Match a a
# jar :: jar ::
# 	/// jar jar
# 	Match jar jar
# from :: from ::
# 	/// from from
# 	Match from from
# one :: one ::
# 	/// one one
# 	Match one one
# of :: of ::
# 	/// of of
# 	Match of of
# the :: the ::
# 	/// the the
# 	Match the the
# shelves :: shelves ::
# 	/// shelves shelves
# 	Match shelves shelves
# as :: as ::
# 	/// as as
# 	Match as as
# she :: she ::
# 	/// she she
# 	Match she she
# passed :: passed ::
# 	/// passed passed
# 	Match passed passed
# it :: it ::
# 	/// it it
# 	Match it it
# was :: was ::
# 	/// was was
# 	Match was was
# labelled :: labelled ::
# 	/// labelled labelled
# 	Match labelled labelled
# orange :: orange ::
# 	/// orange orange
# 	Match orange orange
# marmalade :: marmalade ::
# 	/// marmalade marmalade
# 	Match marmalade marmalade
# but :: but ::
# 	/// but but
# 	Match but but
# to :: to ::
# 	/// to to
# 	Match to to
# her :: her ::
# 	/// her her
# 	Match her her
# great :: great ::
# 	/// great great
# 	Match great great
# disappointment :: disappointment ::
# 	/// disappointment disappointment
# 	Match disappointment disappointment
# it :: it ::
# 	/// it it
# 	Match it it
# was :: was ::
# 	/// was was
# 	Match was was
# empty :: empty ::
# 	/// empty empty
# 	Match empty empty
# she :: she ::
# 	/// she she
# 	Match she she
# did :: did ::
# 	/// did did
# 	Match did did
# not :: not ::
# 	/// not not
# 	Match not not
# like :: like ::
# 	/// like like
# 	Match like like
# to :: to ::
# 	/// to to
# 	Match to to
# drop :: drop ::
# 	/// drop drop
# 	Match drop drop
# the :: the ::
# 	/// the the
# 	Match the the
# jar :: jar ::
# 	/// jar jar
# 	Match jar jar
# for :: for ::
# 	/// for for
# 	Match for for
# fear :: fear ::
# 	/// fear fear
# 	Match fear fear
# of :: of ::
# 	/// of of
# 	Match of of
# killing :: killing ::
# 	/// killing killing
# 	Match killing killing
# somebody :: somebody ::
# 	/// somebody somebody
# 	Match somebody somebody
# so :: so ::
# 	/// so so
# 	Match so so
# she :: she ::
# 	/// she she
# 	Match she she
# managed :: managed ::
# 	/// managed managed
# 	Match managed managed
# to :: to ::
# 	/// to to
# 	Match to to
# put :: put ::
# 	/// put put
# 	Match put put
# it :: it ::
# 	/// it it
# 	Match it it
# into :: into ::
# 	/// into into
# 	Match into into
# one :: one ::
# 	/// one one
# 	Match one one
# of :: of ::
# 	/// of of
# 	Match of of
# the :: the ::
# 	/// the the
# 	Match the the
# cupboards :: cupboards ::
# 	/// cupboards cupboards
# 	Match cupboards cupboards
# as :: as ::
# 	/// as as
# 	Match as as
# she :: she ::
# 	/// she she
# 	Match she she
# fell :: fell ::
# 	/// fell fell
# 	Match fell fell
# past :: past ::
# 	/// past past
# 	Match past past
# it :: it ::
# 	/// it it
# 	Match it it
# Well :: well ::
# 	/// well well
# 	Match well well
# thought :: thought ::
# 	/// thought thought
# 	Match thought thought
# Alice :: alice ::
# 	/// alice alice
# 	Match alice alice
# to :: to ::
# 	/// to to
# 	Match to to
# herself :: herself ::
# 	/// herself herself
# 	Match herself herself
# after :: after ::
# 	/// after after
# 	Match after after
# such :: such ::
# 	/// such such
# 	Match such such
# a :: a ::
# 	/// a a
# 	Match a a
# fall :: fall ::
# 	/// fall fall
# 	Match fall fall
# as :: as ::
# 	/// as as
# 	Match as as
# this :: this ::
# 	/// this this
# 	Match this this
# I :: i ::
# 	/// i i
# 	Match i i
# shall :: shall ::
# 	/// shall shall
# 	Match shall shall
# think :: think ::
# 	/// think think
# 	Match think think
# nothing :: nothing ::
# 	/// nothing nothing
# 	Match nothing nothing
# of :: of ::
# 	/// of of
# 	Match of of
# tumbling :: tumbling ::
# 	/// tumbling tumbling
# 	Match tumbling tumbling
# down :: down ::
# 	/// down down
# 	Match down down
# stairs :: stairs ::
# 	/// stairs stairs
# 	Match stairs stairs
# How :: how ::
# 	/// how how
# 	Match how how
# brave :: brave ::
# 	/// brave brave
# 	Match brave brave
# they :: they ::
# 	/// theyll they
# 	Match they theyll
# ll :: ll ::
# 	/// ll ll
# 	Match ll ll
# all :: all ::
# 	/// all all
# 	Match all all
# think :: think ::
# 	/// think think
# 	Match think think
# me :: me ::
# 	/// me me
# 	Match me me
# at :: at ::
# 	/// at at
# 	Match at at
# home :: home ::
# 	/// home home
# 	Match home home
# Why :: why ::
# 	/// why why
# 	Match why why
# I :: i ::
# 	/// i i
# 	Match i i
# would :: would ::
# 	/// wouldnt would
# 	Match would wouldnt
# nt :: nt ::
# 	/// nt nt
# 	Match nt nt
# say :: say ::
# 	/// say say
# 	Match say say
# anything :: anything ::
# 	/// anything anything
# 	Match anything anything
# about :: about ::
# 	/// about about
# 	Match about about
# it :: it ::
# 	/// it it
# 	Match it it
# even :: even ::
# 	/// even even
# 	Match even even
# if :: if ::
# 	/// if if
# 	Match if if
# I :: i ::
# 	/// i i
# 	Match i i
# fell :: fell ::
# 	/// fell fell
# 	Match fell fell
# off :: off ::
# 	/// off off
# 	Match off off
# the :: the ::
# 	/// the the
# 	Match the the
# top :: top ::
# 	/// top top
# 	Match top top
# of :: of ::
# 	/// of of
# 	Match of of
# the :: the ::
# 	/// the the
# 	Match the the
# house :: house ::
# 	/// house house
# 	Match house house
# Which :: which ::
# 	/// which which
# 	Match which which
# was :: was ::
# 	/// was was
# 	Match was was
# very :: very ::
# 	/// very very
# 	Match very very
# likely :: likely ::
# 	/// likely likely
# 	Match likely likely
# true :: true ::
# 	/// true true
# 	Match true true
# Down :: down ::
# 	/// down down
# 	Match down down
# down :: down ::
# 	/// down down
# 	Match down down
# down :: down ::
# 	/// down down
# 	Match down down
# Would :: would ::
# 	/// would would
# 	Match would would
# the :: the ::
# 	/// the the
# 	Match the the
# fall :: fall ::
# 	/// fall fall
# 	Match fall fall
# never :: never ::
# 	/// never never
# 	Match never never
# come :: come ::
# 	/// come come
# 	Match come come
# to :: to ::
# 	/// to to
# 	Match to to
# an :: an ::
# 	/// an an
# 	Match an an
# end :: end ::
# 	/// end end
# 	Match end end
# I :: i ::
# 	/// i i
# 	Match i i
# wonder :: wonder ::
# 	/// wonder wonder
# 	Match wonder wonder
# how :: how ::
# 	/// how how
# 	Match how how
# many :: many ::
# 	/// many many
# 	Match many many
# miles :: miles ::
# 	/// miles miles
# 	Match miles miles
# I :: i ::
# 	/// ive i
# 	Match i ive
# ve :: ve ::
# 	/// ve ve
# 	Match ve ve
# fallen :: fallen ::
# 	/// fallen fallen
# 	Match fallen fallen
# by :: by ::
# 	/// by by
# 	Match by by
# this :: this ::
# 	/// this this
# 	Match this this
# time :: time ::
# 	/// time time
# 	Match time time
# she :: she ::
# 	/// she she
# 	Match she she
# said :: said ::
# 	/// said said
# 	Match said said
# aloud :: aloud ::
# 	/// aloud aloud
# 	Match aloud aloud
# must :: must ::
# 	/// i must
# 	// must
# 	Match must must
# be :: be ::
# 	/// be be
# 	Match be be
# getting :: getting ::
# 	/// getting getting
# 	Match getting getting
# somewhere :: somewhere ::
# 	/// somewhere somewhere
# 	Match somewhere somewhere
# near :: near ::
# 	/// near near
# 	Match near near
# the :: the ::
# 	/// the the
# 	Match the the
# center :: center ::
# 	/// center center
# 	Match center center
# of :: of ::
# 	/// of of
# 	Match of of
# the :: the ::
# 	/// the the
# 	Match the the
# earth :: earth ::
# 	/// earth earth
# 	Match earth earth
# Let :: let ::
# 	/// let let
# 	Match let let
# me :: me ::
# 	/// me me
# 	Match me me
# see :: see ::
# 	/// see see
# 	Match see see
# that :: that ::
# 	/// that that
# 	Match that that
# would :: would ::
# 	/// would would
# 	Match would would
# be :: be ::
# 	/// be be
# 	Match be be
# four :: four ::
# 	/// four four
# 	Match four four
# thousand :: thousand ::
# 	/// thousand thousand
# 	Match thousand thousand
# miles :: miles ::
# 	/// miles miles
# 	Match miles miles
# down :: down ::
# 	/// down down
# 	Match down down
# I :: i ::
# 	/// i i
# 	Match i i
# think :: think ::
# 	/// think think
# 	Match think think
# for :: for ::
# 	/// for for
# 	Match for for
# you :: you ::
# 	/// you you
# 	Match you you
# see :: see ::
# 	/// see see
# 	Match see see
# Alice :: alice ::
# 	/// alice alice
# 	Match alice alice
# had :: had ::
# 	/// had had
# 	Match had had
# learnt :: learnt ::
# 	/// learnt learnt
# 	Match learnt learnt
# several :: several ::
# 	/// several several
# 	Match several several
# things :: things ::
# 	/// things things
# 	Match things things
# of :: of ::
# 	/// of of
# 	Match of of
# this :: this ::
# 	/// this this
# 	Match this this
# sort :: sort ::
# 	/// sort sort
# 	Match sort sort
# in :: in ::
# 	/// in in
# 	Match in in
# her :: her ::
# 	/// her her
# 	Match her her
# lessons :: lessons ::
# 	/// lessons lessons
# 	Match lessons lessons
# in :: in ::
# 	/// in in
# 	Match in in
# the :: the ::
# 	/// the the
# 	Match the the
# school :: school ::
# 	/// schoolroom school
# 	Match school schoolroom
# room :: room ::
# 	/// room room
# 	Match room room
# and :: and ::
# 	/// and and
# 	Match and and
# though :: though ::
# 	/// though though
# 	Match though though
# this :: this ::
# 	/// this this
# 	Match this this
# was :: was ::
# 	/// was was
# 	Match was was
# not :: not ::
# 	/// not not
# 	Match not not
# a :: a ::
# 	/// a a
# 	Match a a
# very :: very ::
# 	/// very very
# 	Match very very
# good :: good ::
# 	/// good good
# 	Match good good
# opportunity :: opportunity ::
# 	/// opportunity opportunity
# 	Match opportunity opportunity
# for :: for ::
# 	/// for for
# 	Match for for
# showing :: showing ::
# 	/// showing showing
# 	Match showing showing
# off :: off ::
# 	/// off off
# 	Match off off
# her :: her ::
# 	/// her her
# 	Match her her
# knowledge :: knowledge ::
# 	/// knowledge knowledge
# 	Match knowledge knowledge
# as :: as ::
# 	/// as as
# 	Match as as
# there :: there ::
# 	/// there there
# 	Match there there
# was :: was ::
# 	/// was was
# 	Match was was
# no :: no ::
# 	/// no no
# 	Match no no
# one :: one ::
# 	/// one one
# 	Match one one
# to :: to ::
# 	/// to to
# 	Match to to
# listen :: listen ::
# 	/// listen listen
# 	Match listen listen
# to :: to ::
# 	/// to to
# 	Match to to
# her :: her ::
# 	/// her her
# 	Match her her
# still :: still ::
# 	/// still still
# 	Match still still
# it :: it ::
# 	/// it it
# 	Match it it
# was :: was ::
# 	/// was was
# 	Match was was
# good :: good ::
# 	/// good good
# 	Match good good
# practice :: practice ::
# 	/// practice practice
# 	Match practice practice
# to :: to ::
# 	/// to to
# 	Match to to
# say :: say ::
# 	/// say say
# 	Match say say
# it :: it ::
# 	/// it it
# 	Match it it
# over :: over ::
# 	/// over over
# 	Match over over
# yes :: yes ::
# 	/// yes yes
# 	Match yes yes
# that :: that ::
# 	/// thats that
# 	Match that thats
# s :: s ::
# 	/// s s
# 	Match s s
# about :: about ::
# 	/// about about
# 	Match about about
# the :: the ::
# 	/// the the
# 	Match the the
# right :: right ::
# 	/// right right
# 	Match right right
# distance :: distance ::
# 	/// distancebut distance
# 	Match distance distancebut
# but :: but ::
# 	/// but but
# 	Match but but
# then :: then ::
# 	/// then then
# 	Match then then
# I :: i ::
# 	/// i i
# 	Match i i
# wonder :: wonder ::
# 	/// wonder wonder
# 	Match wonder wonder
# what :: what ::
# 	/// what what
# 	Match what what
# Latitude :: latitude ::
# 	/// latitude latitude
# 	Match latitude latitude
# or :: or ::
# 	/// or or
# 	Match or or
# Longitude :: longitude ::
# 	/// longitude longitude
# 	Match longitude longitude
# I :: i ::
# 	/// ive i
# 	Match i ive
# ve :: ve ::
# 	/// ve ve
# 	Match ve ve
# got :: got ::
# 	/// got got
# 	Match got got
# to :: to ::
# 	/// to to
# 	Match to to
# Alice :: alice ::
# 	/// alice alice
# 	Match alice alice
# had :: had ::
# 	/// had had
# 	Match had had
# no :: no ::
# 	/// no no
# 	Match no no
# idea :: idea ::
# 	/// idea idea
# 	Match idea idea
# what :: what ::
# 	/// what what
# 	Match what what
# Latitude :: latitude ::
# 	/// latitude latitude
# 	Match latitude latitude
# was :: was ::
# 	/// was was
# 	Match was was
# or :: or ::
# 	/// or or
# 	Match or or
# Longitude :: longitude ::
# 	/// longitude longitude
# 	Match longitude longitude
# either :: either ::
# 	/// either either
# 	Match either either
# but :: but ::
# 	/// but but
# 	Match but but
# thought :: thought ::
# 	/// thought thought
# 	Match thought thought
# they :: they ::
# 	/// they they
# 	Match they they
# were :: were ::
# 	/// were were
# 	Match were were
# nice :: nice ::
# 	/// nice nice
# 	Match nice nice
# grand :: grand ::
# 	/// grand grand
# 	Match grand grand
# words :: words ::
# 	/// words words
# 	Match words words
# to :: to ::
# 	/// to to
# 	Match to to
# say :: say ::
# 	/// say say
# 	Match say say
# Presently :: presently ::
# 	/// presently presently
# 	Match presently presently
# she :: she ::
# 	/// she she
# 	Match she she
# began :: began ::
# 	/// began began
# 	Match began began
# again :: again ::
# 	/// again again
# 	Match again again
# I :: i ::
# 	/// i i
# 	Match i i
# wonder :: wonder ::
# 	/// wonder wonder
# 	Match wonder wonder
# if :: if ::
# 	/// if if
# 	Match if if
# I :: i ::
# 	/// i i
# 	Match i i
# shall :: shall ::
# 	/// shall shall
# 	Match shall shall
# fall :: fall ::
# 	/// fall fall
# 	Match fall fall
# right :: right ::
# 	/// right right
# 	Match right right
# through :: through ::
# 	/// through through
# 	Match through through
# the :: the ::
# 	/// the the
# 	Match the the
# earth :: earth ::
# 	/// earth earth
# 	Match earth earth
# How :: how ::
# 	/// how how
# 	Match how how
# funny :: funny ::
# 	/// funny funny
# 	Match funny funny
# it :: it ::
# 	/// itll it
# 	Match it itll
# ll :: ll ::
# 	/// ll ll
# 	Match ll ll
# seem :: seem ::
# 	/// seem seem
# 	Match seem seem
# to :: to ::
# 	/// to to
# 	Match to to
# come :: come ::
# 	/// come come
# 	Match come come
# out :: out ::
# 	/// out out
# 	Match out out
# among :: among ::
# 	/// among among
# 	Match among among
# the :: the ::
# 	/// the the
# 	Match the the
# people :: people ::
# 	/// people people
# 	Match people people
# that :: that ::
# 	/// that that
# 	Match that that
# walk :: walk ::
# 	/// walk walk
# 	Match walk walk
# with :: with ::
# 	/// with with
# 	Match with with
# their :: their ::
# 	/// their their
# 	Match their their
# heads :: heads ::
# 	/// heads heads
# 	Match heads heads
# downward :: downward ::
# 	/// downward downward
# 	Match downward downward
# The :: the ::
# 	/// the the
# 	Match the the
# Antipathies :: antipathies ::
# 	/// antipathies antipathies
# 	Match antipathies antipathies
# I :: i ::
# 	/// i i
# 	Match i i
# think :: think ::
# 	/// think think
# 	Match think think
# she :: she ::
# 	/// she she
# 	Match she she
# was :: was ::
# 	/// was was
# 	Match was was
# rather :: rather ::
# 	/// rather rather
# 	Match rather rather
# glad :: glad ::
# 	/// glad glad
# 	Match glad glad
# there :: there ::
# 	/// there there
# 	Match there there
# was :: was ::
# 	/// was was
# 	Match was was
# no :: no ::
# 	/// no no
# 	Match no no
# one :: one ::
# 	/// one one
# 	Match one one
# listening :: listening ::
# 	/// listening listening
# 	Match listening listening
# this :: this ::
# 	/// this this
# 	Match this this
# time :: time ::
# 	/// time time
# 	Match time time
# as :: as ::
# 	/// as as
# 	Match as as
# it :: it ::
# 	/// it it
# 	Match it it
# did :: did ::
# 	/// didnt did
# 	Match did didnt
# nt :: nt ::
# 	/// nt nt
# 	Match nt nt
# sound :: sound ::
# 	/// sound sound
# 	Match sound sound
# at :: at ::
# 	/// at at
# 	Match at at
# all :: all ::
# 	/// all all
# 	Match all all
# the :: the ::
# 	/// the the
# 	Match the the
# right :: right ::
# 	/// right right
# 	Match right right
# word :: word ::
# 	/// word word
# 	Match word word
# but :: but ::
# 	/// but but
# 	Match but but
# I :: i ::
# 	/// i i
# 	Match i i
# shall :: shall ::
# 	/// shall shall
# 	Match shall shall
# have :: have ::
# 	/// have have
# 	Match have have
# to :: to ::
# 	/// to to
# 	Match to to
# ask :: ask ::
# 	/// ask ask
# 	Match ask ask
# them :: them ::
# 	/// them them
# 	Match them them
# what :: what ::
# 	/// what what
# 	Match what what
# the :: the ::
# 	/// the the
# 	Match the the
# name :: name ::
# 	/// name name
# 	Match name name
# of :: of ::
# 	/// of of
# 	Match of of
# the :: the ::
# 	/// the the
# 	Match the the
# country :: country ::
# 	/// country country
# 	Match country country
# is :: is ::
# 	/// is is
# 	Match is is
# you :: you ::
# 	/// you you
# 	Match you you
# know :: know ::
# 	/// know know
# 	Match know know
# Please :: please ::
# 	/// please please
# 	Match please please
# Maam :: maam ::
# 	/// maam maam
# 	Match maam maam
# is :: is ::
# 	/// is is
# 	Match is is
# this :: this ::
# 	/// this this
# 	Match this this
# New :: new ::
# 	/// new new
# 	Match new new
# Zealand :: zealand ::
# 	/// zealand zealand
# 	Match zealand zealand
# or :: or ::
# 	/// or or
# 	Match or or
# Australia :: australia ::
# 	/// australia australia
# 	Match australia australia
# and :: and ::
# 	/// and and
# 	Match and and
# she :: she ::
# 	/// she she
# 	Match she she
# tried :: tried ::
# 	/// tried tried
# 	Match tried tried
# to :: to ::
# 	/// to to
# 	Match to to
# curtsey :: curtsey ::
# 	/// curtsey curtsey
# 	Match curtsey curtsey
# as :: as ::
# 	/// as as
# 	Match as as
# she :: she ::
# 	/// she she
# 	Match she she
# spoke :: spoke ::
# 	/// spokefancy spoke
# 	Match spoke spokefancy
# fancy :: fancy ::
# 	/// fancy fancy
# 	Match fancy fancy
# curtseying :: curtseying ::
# 	/// curtseying curtseying
# 	Match curtseying curtseying
# as :: as ::
# 	/// as as
# 	Match as as
# you :: you ::
# 	/// youre you
# 	Match you youre
# re :: re ::
# 	/// re re
# 	Match re re
# falling :: falling ::
# 	/// falling falling
# 	Match falling falling
# through :: through ::
# 	/// through through
# 	Match through through
# the :: the ::
# 	/// the the
# 	Match the the
# air :: air ::
# 	/// air air
# 	Match air air
# Do :: do ::
# 	/// do do
# 	Match do do
# you :: you ::
# 	/// you you
# 	Match you you
# think :: think ::
# 	/// think think
# 	Match think think
# you :: you ::
# 	/// you you
# 	Match you you
# could :: could ::
# 	/// could could
# 	Match could could
# manage :: manage ::
# 	/// manage manage
# 	Match manage manage
# it :: it ::
# 	/// it it
# 	Match it it
# And :: and ::
# 	/// and and
# 	Match and and
# what :: what ::
# 	/// what what
# 	Match what what
# an :: an ::
# 	/// an an
# 	Match an an
# ignorant :: ignorant ::
# 	/// ignorant ignorant
# 	Match ignorant ignorant
# little :: little ::
# 	/// little little
# 	Match little little
# girl :: girl ::
# 	/// girl girl
# 	Match girl girl
# she :: she ::
# 	/// shell she
# 	Match she shell
# ll :: ll ::
# 	/// ll ll
# 	Match ll ll
# think :: think ::
# 	/// think think
# 	Match think think
# me :: me ::
# 	/// me me
# 	Match me me
# for :: for ::
# 	/// for for
# 	Match for for
# asking :: asking ::
# 	/// asking asking
# 	Match asking asking
# No :: no ::
# 	/// no no
# 	Match no no
# it :: it ::
# 	/// itll it
# 	Match it itll
# ll :: ll ::
# 	/// ll ll
# 	Match ll ll
# never :: never ::
# 	/// never never
# 	Match never never
# do :: do ::
# 	/// do do
# 	Match do do
# to :: to ::
# 	/// to to
# 	Match to to
# ask :: ask ::
# 	/// ask ask
# 	Match ask ask
# perhaps :: perhaps ::
# 	/// perhaps perhaps
# 	Match perhaps perhaps
# I :: i ::
# 	/// i i
# 	Match i i
# shall :: shall ::
# 	/// shall shall
# 	Match shall shall
# see :: see ::
# 	/// see see
# 	Match see see
# it :: it ::
# 	/// it it
# 	Match it it
# written :: written ::
# 	/// written written
# 	Match written written
# up :: up ::
# 	/// up up
# 	Match up up
# somewhere :: somewhere ::
# 	/// somewhere somewhere
# 	Match somewhere somewhere
# Down :: down ::
# 	/// down down
# 	Match down down
# down :: down ::
# 	/// down down
# 	Match down down
# down :: down ::
# 	/// down down
# 	Match down down
# There :: there ::
# 	/// there there
# 	Match there there
# was :: was ::
# 	/// was was
# 	Match was was
# nothing :: nothing ::
# 	/// nothing nothing
# 	Match nothing nothing
# else :: else ::
# 	/// else else
# 	Match else else
# to :: to ::
# 	/// to to
# 	Match to to
# do :: do ::
# 	/// do do
# 	Match do do
# so :: so ::
# 	/// so so
# 	Match so so
# Alice :: alice ::
# 	/// alice alice
# 	Match alice alice
# soon :: soon ::
# 	/// soon soon
# 	Match soon soon
# began :: began ::
# 	/// began began
# 	Match began began
# talking :: talking ::
# 	/// talking talking
# 	Match talking talking
# again :: again ::
# 	/// again again
# 	Match again again
# Dinah :: dinah ::
# 	/// dinahll dinah
# 	Match dinah dinahll
# ll :: ll ::
# 	/// ll ll
# 	Match ll ll
# miss :: miss ::
# 	/// miss miss
# 	Match miss miss
# me :: me ::
# 	/// me me
# 	Match me me
# very :: very ::
# 	/// very very
# 	Match very very
# much :: much ::
# 	/// much much
# 	Match much much
# tonight :: tonight ::
# 	/// tonight tonight
# 	Match tonight tonight
# I :: i ::
# 	/// i i
# 	Match i i
# should :: should ::
# 	/// should should
# 	Match should should
# think :: think ::
# 	/// think think
# 	Match think think
# Dinah :: dinah ::
# 	/// dinah dinah
# 	Match dinah dinah
# was :: was ::
# 	/// was was
# 	Match was was
# the :: the ::
# 	/// the the
# 	Match the the
# cat :: cat ::
# 	/// cat cat
# 	Match cat cat
# I :: i ::
# 	/// i i
# 	Match i i
# hope :: hope ::
# 	/// hope hope
# 	Match hope hope
# they :: they ::
# 	/// theyll they
# 	Match they theyll
# ll :: ll ::
# 	/// ll ll
# 	Match ll ll
# remember :: remember ::
# 	/// remember remember
# 	Match remember remember
# her :: her ::
# 	/// her her
# 	Match her her
# saucer :: saucer ::
# 	/// saucer saucer
# 	Match saucer saucer
# of :: of ::
# 	/// of of
# 	Match of of
# milk :: milk ::
# 	/// milk milk
# 	Match milk milk
# at :: at ::
# 	/// at at
# 	Match at at
# tea :: tea ::
# 	/// teatime tea
# 	Match tea teatime
# time :: time ::
# 	/// time time
# 	Match time time
# Dinah :: dinah ::
# 	/// dinah dinah
# 	Match dinah dinah
# my :: my ::
# 	/// my my
# 	Match my my
# dear :: dear ::
# 	/// dear dear
# 	Match dear dear
# I :: i ::
# 	/// i i
# 	Match i i
# wish :: wish ::
# 	/// wish wish
# 	Match wish wish
# you :: you ::
# 	/// you you
# 	Match you you
# were :: were ::
# 	/// were were
# 	Match were were
# down :: down ::
# 	/// down down
# 	Match down down
# here :: here ::
# 	/// here here
# 	Match here here
# with :: with ::
# 	/// with with
# 	Match with with
# me :: me ::
# 	/// me me
# 	Match me me
# There :: there ::
# 	/// there there
# 	Match there there
# are :: are ::
# 	/// are are
# 	Match are are
# no :: no ::
# 	/// no no
# 	Match no no
# mice :: mice ::
# 	/// mice mice
# 	Match mice mice
# in :: in ::
# 	/// in in
# 	Match in in
# the :: the ::
# 	/// the the
# 	Match the the
# air :: air ::
# 	/// air air
# 	Match air air
# I :: i ::
# 	/// im i
# 	Match i im
# m :: m ::
# 	/// m m
# 	Match m m
# afraid :: afraid ::
# 	/// afraid afraid
# 	Match afraid afraid
# but :: but ::
# 	/// but but
# 	Match but but
# you :: you ::
# 	/// you you
# 	Match you you
# might :: might ::
# 	/// might might
# 	Match might might
# catch :: catch ::
# 	/// catch catch
# 	Match catch catch
# a :: a ::
# 	/// a a
# 	Match a a
# bat :: bat ::
# 	/// bat bat
# 	Match bat bat
# and :: and ::
# 	/// and and
# 	Match and and
# that :: that ::
# 	/// thats that
# 	Match that thats
# s :: s ::
# 	/// s s
# 	Match s s
# very :: very ::
# 	/// very very
# 	Match very very
# like :: like ::
# 	/// like like
# 	Match like like
# a :: a ::
# 	/// a a
# 	Match a a
# mouse :: mouse ::
# 	/// mouse mouse
# 	Match mouse mouse
# you :: you ::
# 	/// you you
# 	Match you you
# know :: know ::
# 	/// know know
# 	Match know know
# But :: but ::
# 	/// but but
# 	Match but but
# do :: do ::
# 	/// do do
# 	Match do do
# cats :: cats ::
# 	/// cats cats
# 	Match cats cats
# eat :: eat ::
# 	/// eat eat
# 	Match eat eat
# bats :: bats ::
# 	/// bats bats
# 	Match bats bats
# I :: i ::
# 	/// i i
# 	Match i i
# wonder :: wonder ::
# 	/// wonder wonder
# 	Match wonder wonder
# And :: and ::
# 	/// and and
# 	Match and and
# here :: here ::
# 	/// here here
# 	Match here here
# Alice :: alice ::
# 	/// alice alice
# 	Match alice alice
# began :: began ::
# 	/// began began
# 	Match began began
# to :: to ::
# 	/// to to
# 	Match to to
# get :: get ::
# 	/// get get
# 	Match get get
# rather :: rather ::
# 	/// rather rather
# 	Match rather rather
# sleepy :: sleepy ::
# 	/// sleepy sleepy
# 	Match sleepy sleepy
# and :: and ::
# 	/// and and
# 	Match and and
# went :: went ::
# 	/// went went
# 	Match went went
# on :: on ::
# 	/// on on
# 	Match on on
# saying :: saying ::
# 	/// saying saying
# 	Match saying saying
# to :: to ::
# 	/// to to
# 	Match to to
# herself :: herself ::
# 	/// herself herself
# 	Match herself herself
# in :: in ::
# 	/// in in
# 	Match in in
# a :: a ::
# 	/// a a
# 	Match a a
# dreamy :: dreamy ::
# 	/// dreamy dreamy
# 	Match dreamy dreamy
# sort :: sort ::
# 	/// sort sort
# 	Match sort sort
# of :: of ::
# 	/// of of
# 	Match of of
# way :: way ::
# 	/// way way
# 	Match way way
# Do :: do ::
# 	/// do do
# 	Match do do
# cats :: cats ::
# 	/// cats cats
# 	Match cats cats
# eat :: eat ::
# 	/// eat eat
# 	Match eat eat
# bats :: bats ::
# 	/// bats bats
# 	Match bats bats
# Do :: do ::
# 	/// do do
# 	Match do do
# cats :: cats ::
# 	/// cats cats
# 	Match cats cats
# eat :: eat ::
# 	/// eat eat
# 	Match eat eat
# bats :: bats ::
# 	/// bats bats
# 	Match bats bats
# and :: and ::
# 	/// and and
# 	Match and and
# sometimes :: sometimes ::
# 	/// sometimes sometimes
# 	Match sometimes sometimes
# Do :: do ::
# 	/// do do
# 	Match do do
# bats :: bats ::
# 	/// bats bats
# 	Match bats bats
# eat :: eat ::
# 	/// eat eat
# 	Match eat eat
# cats :: cats ::
# 	/// cats cats
# 	Match cats cats
# for :: for ::
# 	/// for for
# 	Match for for
# you :: you ::
# 	/// you you
# 	Match you you
# see :: see ::
# 	/// see see
# 	Match see see
# as :: as ::
# 	/// as as
# 	Match as as
# she :: she ::
# 	/// she she
# 	Match she she
# could :: could ::
# 	/// couldnt could
# 	Match could couldnt
# nt :: nt ::
# 	/// nt nt
# 	Match nt nt
# answer :: answer ::
# 	/// answer answer
# 	Match answer answer
# either :: either ::
# 	/// either either
# 	Match either either
# question :: question ::
# 	/// question question
# 	Match question question
# it :: it ::
# 	/// it it
# 	Match it it
# did :: did ::
# 	/// didnt did
# 	Match did didnt
# nt :: nt ::
# 	/// nt nt
# 	Match nt nt
# much :: much ::
# 	/// much much
# 	Match much much
# matter :: matter ::
# 	/// matter matter
# 	Match matter matter
# which :: which ::
# 	/// which which
# 	Match which which
# way :: way ::
# 	/// way way
# 	Match way way
# she :: she ::
# 	/// she she
# 	Match she she
# put :: put ::
# 	/// put put
# 	Match put put
# it :: it ::
# 	/// it it
# 	Match it it
# She :: she ::
# 	/// she she
# 	Match she she
# felt :: felt ::
# 	/// felt felt
# 	Match felt felt
# that :: that ::
# 	/// that that
# 	Match that that
# she :: she ::
# 	/// she she
# 	Match she she
# was :: was ::
# 	/// was was
# 	Match was was
# dozing :: dozing ::
# 	/// dozing dozing
# 	Match dozing dozing
# off :: off ::
# 	/// off off
# 	Match off off
# and :: and ::
# 	/// and and
# 	Match and and
# had :: had ::
# 	/// had had
# 	Match had had
# just :: just ::
# 	/// just just
# 	Match just just
# begun :: begun ::
# 	/// begun begun
# 	Match begun begun
# to :: to ::
# 	/// to to
# 	Match to to
# dream :: dream ::
# 	/// dream dream
# 	Match dream dream
# that :: that ::
# 	/// that that
# 	Match that that
# she :: she ::
# 	/// she she
# 	Match she she
# was :: was ::
# 	/// was was
# 	Match was was
# walking :: walking ::
# 	/// walking walking
# 	Match walking walking
# hand :: hand ::
# 	/// hand hand
# 	Match hand hand
# in :: in ::
# 	/// in in
# 	Match in in
# hand :: hand ::
# 	/// hand hand
# 	Match hand hand
# with :: with ::
# 	/// with with
# 	Match with with
# Dinah :: dinah ::
# 	/// dinah dinah
# 	Match dinah dinah
# and :: and ::
# 	/// and and
# 	Match and and
# saying :: saying ::
# 	/// saying saying
# 	Match saying saying
# to :: to ::
# 	/// to to
# 	Match to to
# her :: her ::
# 	/// her her
# 	Match her her
# very :: very ::
# 	/// very very
# 	Match very very
# earnestly :: earnestly ::
# 	/// earnestly earnestly
# 	Match earnestly earnestly
# Now :: now ::
# 	/// now now
# 	Match now now
# Dinah :: dinah ::
# 	/// dinah dinah
# 	Match dinah dinah
# tell :: tell ::
# 	/// tell tell
# 	Match tell tell
# me :: me ::
# 	/// me me
# 	Match me me
# the :: the ::
# 	/// the the
# 	Match the the
# truth :: truth ::
# 	/// truth truth
# 	Match truth truth
# did :: did ::
# 	/// did did
# 	Match did did
# you :: you ::
# 	/// you you
# 	Match you you
# ever :: ever ::
# 	/// ever ever
# 	Match ever ever
# eat :: eat ::
# 	/// eat eat
# 	Match eat eat
# a :: a ::
# 	/// a a
# 	Match a a
# bat :: bat ::
# 	/// bat bat
# 	Match bat bat
# when :: when ::
# 	/// when when
# 	Match when when
# suddenly :: suddenly ::
# 	/// suddenly suddenly
# 	Match suddenly suddenly
# thump :: thump ::
# 	/// thump thump
# 	Match thump thump
# thump :: thump ::
# 	/// thump thump
# 	Match thump thump
# down :: down ::
# 	/// down down
# 	Match down down
# she :: she ::
# 	/// she she
# 	Match she she
# came :: came ::
# 	/// came came
# 	Match came came
# upon :: upon ::
# 	/// upon upon
# 	Match upon upon
# a :: a ::
# 	/// a a
# 	Match a a
# heap :: heap ::
# 	/// heap heap
# 	Match heap heap
# of :: of ::
# 	/// of of
# 	Match of of
# sticks :: sticks ::
# 	/// sticks sticks
# 	Match sticks sticks
# and :: and ::
# 	/// and and
# 	Match and and
# dry :: dry ::
# 	/// dry dry
# 	Match dry dry
# leaves :: leaves ::
# 	/// leaves leaves
# 	Match leaves leaves
# and :: and ::
# 	/// and and
# 	Match and and
# the :: the ::
# 	/// the the
# 	Match the the
# fall :: fall ::
# 	/// fall fall
# 	Match fall fall
# was :: was ::
# 	/// was was
# 	Match was was
# over :: over ::
# 	/// over over
# 	Match over over
# Alice :: alice ::
# 	/// alice alice
# 	Match alice alice
# was :: was ::
# 	/// was was
# 	Match was was
# not :: not ::
# 	/// not not
# 	Match not not
# a :: a ::
# 	/// a a
# 	Match a a
# bit :: bit ::
# 	/// bit bit
# 	Match bit bit
# hurt :: hurt ::
# 	/// hurt hurt
# 	Match hurt hurt
# and :: and ::
# 	/// and and
# 	Match and and
# she :: she ::
# 	/// she she
# 	Match she she
# jumped :: jumped ::
# 	/// jumped jumped
# 	Match jumped jumped
# up :: up ::
# 	/// up up
# 	Match up up
# onto :: onto ::
# 	/// onto onto
# 	Match onto onto
# her :: her ::
# 	/// her her
# 	Match her her
# feet :: feet ::
# 	/// feet feet
# 	Match feet feet
# in :: in ::
# 	/// in in
# 	Match in in
# a :: a ::
# 	/// a a
# 	Match a a
# moment :: moment ::
# 	/// moment moment
# 	Match moment moment
# she :: she ::
# 	/// she she
# 	Match she she
# looked :: looked ::
# 	/// looked looked
# 	Match looked looked
# up :: up ::
# 	/// up up
# 	Match up up
# but :: but ::
# 	/// but but
# 	Match but but
# it :: it ::
# 	/// it it
# 	Match it it
# was :: was ::
# 	/// was was
# 	Match was was
# all :: all ::
# 	/// all all
# 	Match all all
# dark :: dark ::
# 	/// dark dark
# 	Match dark dark
# overhead :: overhead ::
# 	/// overhead overhead
# 	Match overhead overhead
# before :: before ::
# 	/// before before
# 	Match before before
# her :: her ::
# 	/// her her
# 	Match her her
# was :: was ::
# 	/// was was
# 	Match was was
# another :: another ::
# 	/// another another
# 	Match another another
# long :: long ::
# 	/// long long
# 	Match long long
# passage :: passage ::
# 	/// passage passage
# 	Match passage passage
# and :: and ::
# 	/// and and
# 	Match and and
# ...
# 	/// at at
# 	Match at at
# once :: once ::
# 	/// once once
# 	Match once once
# but :: but ::
# 	/// but but
# 	Match but but
# alas :: alas ::
# 	/// alas alas
# 	Match alas alas
# for :: for ::
# 	/// for for
# 	Match for for
# poor :: poor ::
# 	/// poor poor
# 	Match poor poor
# Alice :: alice ::
# 	/// alice alice
# 	Match alice alice
# when :: when ::
# 	/// when when
# 	Match when when
# she :: she ::
# 	/// she she
# 	Match she she
# got :: got ::
# 	/// got got
# 	Match got got
# to :: to ::
# 	/// to to
# 	Match to to
# the :: the ::
# 	/// the the
# 	Match the the
# door :: door ::
# 	/// door door
# 	Match door door
# she :: she ::
# 	/// she she
# 	Match she she
# found :: found ::
# 	/// found found
# 	Match found found
# she :: she ::
# 	/// she she
# 	Match she she
# d :: d ::
# 	/// had d
# 	Match d had
# forgotten :: forgotten ::
# 	/// ad forgotten
# 	// forgotten
# 	Match forgotten forgotten
# the :: the ::
# 	/// the the
# 	Match the the
# little :: little ::
# 	/// little little
# 	Match little little
# golden :: golden ::
# 	/// golden golden
# 	Match golden golden
# key :: key ::
# 	/// key key
# 	Match key key
# and :: and ::
# 	/// and and
# 	Match and and
# when :: when ::
# 	/// when when
# 	Match when when
# she :: she ::
# 	/// she she
# 	Match she she
# went :: went ::
# 	/// went went
# 	Match went went
# back :: back ::
# 	/// back back
# 	Match back back
# to :: to ::
# 	/// to to
# 	Match to to
# the :: the ::
# 	/// the the
# 	Match the the
# table :: table ::
# 	/// table table
# 	Match table table
# for :: for ::
# 	/// for for
# 	Match for for
# it :: it ::
# 	/// it it
# 	Match it it
# she :: she ::
# 	/// she she
# 	Match she she
# found :: found ::
# 	/// found found
# 	Match found found
# she :: she ::
# 	/// she she
# 	Match she she
# could :: could ::
# 	/// could could
# 	Match could could
# not :: not ::
# 	/// not not
# 	Match not not
# possibly :: possibly ::
# 	/// possibly possibly
# 	Match possibly possibly
# reach :: reach ::
# 	/// reach reach
# 	Match reach reach
# it :: it ::
# 	/// it it
# 	Match it it
# she :: she ::
# 	/// she she
# 	Match she she
# could :: could ::
# 	/// could could
# 	Match could could
# see :: see ::
# 	/// see see
# 	Match see see
# it :: it ::
# 	/// it it
# 	Match it it
# quite :: quite ::
# 	/// quite quite
# 	Match quite quite
# plainly :: plainly ::
# 	/// plainly plainly
# 	Match plainly plainly
# through :: through ::
# 	/// through through
# 	Match through through
# the :: the ::
# 	/// the the
# 	Match the the
# glass :: glass ::
# 	/// glass glass
# 	Match glass glass
# and :: and ::
# 	/// and and
# 	Match and and
# she :: she ::
# 	/// she she
# 	Match she she
# tried :: tried ::
# 	/// tried tried
# 	Match tried tried
# her :: her ::
# 	/// her her
# 	Match her her
# best :: best ::
# 	/// best best
# 	Match best best
# to :: to ::
# 	/// to to
# 	Match to to
# climb :: climb ::
# 	/// climb climb
# 	Match climb climb
# up :: up ::
# 	/// up up
# 	Match up up
# one :: one ::
# 	/// one one
# 	Match one one
# of :: of ::
# 	/// of of
# 	Match of of
# the :: the ::
# 	/// the the
# 	Match the the
# legs :: legs ::
# 	/// legs legs
# 	Match legs legs
# of :: of ::
# 	/// of of
# 	Match of of
# the :: the ::
# 	/// the the
# 	Match the the
# table :: table ::
# 	/// table table
# 	Match table table
# but :: but ::
# 	/// but but
# 	Match but but
# it :: it ::
# 	/// it it
# 	Match it it
# was :: was ::
# 	/// was was
# 	Match was was
# too :: too ::
# 	/// too too
# 	Match too too
# slippery :: slippery ::
# 	/// slippery slippery
# 	Match slippery slippery
# and :: and ::
# 	/// and and
# 	Match and and
# when :: when ::
# 	/// when when
# 	Match when when
# she :: she ::
# 	/// she she
# 	Match she she
# had :: had ::
# 	/// had had
# 	Match had had
# tired :: tired ::
# 	/// tired tired
# 	Match tired tired
# herself :: herself ::
# 	/// herself herself
# 	Match herself herself
# out :: out ::
# 	/// out out
# 	Match out out
# with :: with ::
# 	/// with with
# 	Match with with
# trying :: trying ::
# 	/// trying trying
# 	Match trying trying
# the :: the ::
# 	/// the the
# 	Match the the
# poor :: poor ::
# 	/// poor poor
# 	Match poor poor
# little :: little ::
# 	/// little little
# 	Match little little
# thing :: thing ::
# 	/// thing thing
# 	Match thing thing
# sat :: sat ::
# 	/// sat sat
# 	Match sat sat
# down :: down ::
# 	/// down down
# 	Match down down
# and :: and ::
# 	/// and and
# 	Match and and
# cried :: cried ::
# 	/// cried cried
# 	Match cried cried
# Come :: come ::
# 	/// come come
# 	Match come come
# there :: there ::
# 	/// theres there
# 	Match there theres
# s :: s ::
# 	/// s s
# 	Match s s
# no :: no ::
# 	/// no no
# 	Match no no
# use :: use ::
# 	/// use use
# 	Match use use
# crying :: crying ::
# 	/// in crying
# 	// crying
# 	Match crying crying
# like :: like ::
# 	/// like like
# 	Match like like
# that :: that ::
# 	/// that that
# 	Match that that
# said :: said ::
# 	/// said said
# 	Match said said
# Alice :: alice ::
# 	/// alice alice
# 	Match alice alice
# to :: to ::
# 	/// to to
# 	Match to to
# herself :: herself ::
# 	/// herself herself
# 	Match herself herself
# rather :: rather ::
# 	/// rather rather
# 	Match rather rather
# sharply :: sharply ::
# 	/// sharply sharply
# 	Match sharply sharply
# I :: i ::
# 	/// i i
# 	Match i i
# advise :: advise ::
# 	/// advise advise
# 	Match advise advise
# you :: you ::
# 	/// you you
# 	Match you you
# to :: to ::
# 	/// to to
# 	Match to to
# leave :: leave ::
# 	/// leave leave
# 	Match leave leave
# off :: off ::
# 	/// off off
# 	Match off off
# this :: this ::
# 	/// this this
# 	Match this this
# minute :: minute ::
# 	/// minute minute
# 	Match minute minute
# She :: she ::
# 	/// she she
# 	Match she she
# generally :: generally ::
# 	/// generally generally
# 	Match generally generally
# gave :: gave ::
# 	/// gave gave
# 	Match gave gave
# herself :: herself ::
# 	/// herself herself
# 	Match herself herself
# very :: very ::
# 	/// very very
# 	Match very very
# good :: good ::
# 	/// good good
# 	Match good good
# advice :: advice ::
# 	/// advice advice
# 	Match advice advice
# though :: though ::
# 	/// though though
# 	Match though though
# she :: she ::
# 	/// she she
# 	Match she she
# very :: very ::
# 	/// very very
# 	Match very very
# seldom :: seldom ::
# 	/// seldom seldom
# 	Match seldom seldom
# followed :: followed ::
# 	/// followed followed
# 	Match followed followed
# it :: it ::
# 	/// it it
# 	Match it it
# and :: and ::
# 	/// and and
# 	Match and and
# sometimes :: sometimes ::
# 	/// sometimes sometimes
# 	Match sometimes sometimes
# she :: she ::
# 	/// she she
# 	Match she she
# scolded :: scolded ::
# 	/// scolded scolded
# 	Match scolded scolded
# herself :: herself ::
# 	/// herself herself
# 	Match herself herself
# so :: so ::
# 	/// so so
# 	Match so so
# severely :: severely ::
# 	/// severely severely
# 	Match severely severely
# as :: as ::
# 	/// as as
# 	Match as as
# to :: to ::
# 	/// to to
# 	Match to to
# bring :: bring ::
# 	/// bring bring
# 	Match bring bring
# tears :: tears ::
# 	/// tears tears
# 	Match tears tears
# into :: into ::
# 	/// into into
# 	Match into into
# her :: her ::
# 	/// her her
# 	Match her her
# eyes :: eyes ::
# 	/// eyes eyes
# 	Match eyes eyes
# she :: she ::
# 	/// she she
# 	Match she she
# once :: once ::
# 	/// once once
# 	Match once once
# remembered :: remembered ::
# 	/// remembered remembered
# 	Match remembered remembered
# trying :: trying ::
# 	/// trying trying
# 	Match trying trying
# to :: to ::
# 	/// to to
# 	Match to to
# box :: box ::
# 	/// box box
# 	Match box box
# her :: her ::
# 	/// her her
# 	Match her her
# own :: own ::
# 	/// own own
# 	Match own own
# ears :: ears ::
# 	/// ears ears
# 	Match ears ears
# for :: for ::
# 	/// for for
# 	Match for for
# having :: having ::
# 	/// having having
# 	Match having having
# cheated :: cheated ::
# 	/// cheated cheated
# 	Match cheated cheated
# herself :: herself ::
# 	/// herself herself
# 	Match herself herself
# in :: in ::
# 	/// in in
# 	Match in in
# a :: a ::
# 	/// a a
# 	Match a a
# game :: game ::
# 	/// game game
# 	Match game game
# of :: of ::
# 	/// of of
# 	Match of of
# croquet :: croquet ::
# 	/// croquet croquet
# 	Match croquet croquet
# she :: she ::
# 	/// she she
# 	Match she she
# was :: was ::
# 	/// was was
# 	Match was was
# playing :: playing ::
# 	/// playing playing
# 	Match playing playing
# against :: against ::
# 	/// against against
# 	Match against against
# herself :: herself ::
# 	/// herself herself
# 	Match herself herself
# for :: for ::
# 	/// for for
# 	Match for for
# this :: this ::
# 	/// this this
# 	Match this this
# curious :: curious ::
# 	/// curious curious
# 	Match curious curious
# child :: child ::
# 	/// child child
# 	Match child child
# was :: was ::
# 	/// was was
# 	Match was was
# fond :: fond ::
# 	/// very fond
# 	// fond
# 	Match fond fond
# of :: of ::
# 	/// of of
# 	Match of of
# pretending :: pretending ::
# 	/// pretending pretending
# 	Match pretending pretending
# to :: to ::
# 	/// to to
# 	Match to to
# be :: be ::
# 	/// be be
# 	Match be be
# two :: two ::
# 	/// two two
# 	Match two two
# people :: people ::
# 	/// people people
# 	Match people people
# But :: but ::
# 	/// but but
# 	Match but but
# it :: it ::
# 	/// its it
# 	Match it its
# s :: s ::
# 	/// s s
# 	Match s s
# no :: no ::
# 	/// no no
# 	Match no no
# use :: use ::
# 	/// use use
# 	Match use use
# now :: now ::
# 	/// now now
# 	Match now now
# thought :: thought ::
# 	/// thought thought
# 	Match thought thought
# poor :: poor ::
# 	/// poor poor
# 	Match poor poor
# Alice :: alice ::
# 	/// alice alice
# 	Match alice alice
# to :: to ::
# 	/// to to
# 	Match to to
# pretend :: pretend ::
# 	/// pretend pretend
# 	Match pretend pretend
# to :: to ::
# 	/// to to
# 	Match to to
# be :: be ::
# 	/// be be
# 	Match be be
# two :: two ::
# 	/// two two
# 	Match two two
# people :: people ::
# 	/// people people
# 	Match people people
# Why :: why ::
# 	/// why why
# 	Match why why
# there :: there ::
# 	/// theres there
# 	Match there theres
# s :: s ::
# 	/// s s
# 	Match s s
# hardly :: hardly ::
# 	/// hardly hardly
# 	Match hardly hardly
# enough :: enough ::
# 	/// enough enough
# 	Match enough enough
# of :: of ::
# 	/// of of
# 	Match of of
# me :: me ::
# 	/// me me
# 	Match me me
# to :: to ::
# 	/// left to
# 	// to
# 	Match to to
# make :: make ::
# 	/// make make
# 	Match make make
# one :: one ::
# 	/// one one
# 	Match one one
# respectable :: respectable ::
# 	/// respectable respectable
# 	Match respectable respectable
# person :: person ::
# 	/// person person
# 	Match person person
# Soon :: soon ::
# 	/// soon soon
# 	Match soon soon
# her :: her ::
# 	/// her her
# 	Match her her
# eye :: eye ::
# 	/// eye eye
# 	Match eye eye
# fell :: fell ::
# 	/// fell fell
# 	Match fell fell
# on :: on ::
# 	/// on on
# 	Match on on
# a :: a ::
# 	/// a a
# 	Match a a
# little :: little ::
# 	/// little little
# 	Match little little
# glass :: glass ::
# 	/// glass glass
# 	Match glass glass
# box :: box ::
# 	/// box box
# 	Match box box
# that :: that ::
# 	/// that that
# 	Match that that
# was :: was ::
# 	/// was was
# 	Match was was
# lying :: lying ::
# 	/// lying lying
# 	Match lying lying
# under :: under ::
# 	/// under under
# 	Match under under
# the :: the ::
# 	/// the the
# 	Match the the
# table :: table ::
# 	/// table table
# 	Match table table
# she :: she ::
# 	/// she she
# 	Match she she
# opened :: opened ::
# 	/// opened opened
# 	Match opened opened
# it :: it ::
# 	/// it it
# 	Match it it
# and :: and ::
# 	/// and and
# 	Match and and
# found :: found ::
# 	/// found found
# 	Match found found
# in :: in ::
# 	/// in in
# 	Match in in
# it :: it ::
# 	/// it it
# 	Match it it
# a :: a ::
# 	/// a a
# 	Match a a
# very :: very ::
# 	/// very very
# 	Match very very
# small :: small ::
# 	/// small small
# 	Match small small
# cake :: cake ::
# 	/// cake cake
# 	Match cake cake
# on :: on ::
# 	/// on on
# 	Match on on
# which :: which ::
# 	/// which which
# 	Match which which
# the :: the ::
# 	/// the the
# 	Match the the
# words :: words ::
# 	/// words words
# 	Match words words
# eat :: eat ::
# 	/// eat eat
# 	Match eat eat
# me :: me ::
# 	/// me me
# 	Match me me
# were :: were ::
# 	/// were were
# 	Match were were
# beautifully :: beautifully ::
# 	/// beautifully beautifully
# 	Match beautifully beautifully
# marked :: marked ::
# 	/// marked marked
# 	Match marked marked
# in :: in ::
# 	/// in in
# 	Match in in
# currants :: currants ::
# 	/// currants currants
# 	Match currants currants
# Well :: well ::
# 	/// well well
# 	Match well well
# I :: i ::
# 	/// ill i
# 	Match i ill
# ll :: ll ::
# 	/// ll ll
# 	Match ll ll
# eat :: eat ::
# 	/// eat eat
# 	Match eat eat
# it :: it ::
# 	/// it it
# 	Match it it
# said :: said ::
# 	/// said said
# 	Match said said
# Alice :: alice ::
# 	/// alice alice
# 	Match alice alice
# and :: and ::
# 	/// and and
# 	Match and and
# if :: if ::
# 	/// if if
# 	Match if if
# it :: it ::
# 	/// it it
# 	Match it it
# makes :: makes ::
# 	/// makes makes
# 	Match makes makes
# me :: me ::
# 	/// me me
# 	Match me me
# grow :: grow ::
# 	/// grow grow
# 	Match grow grow
# larger :: larger ::
# 	/// larger larger
# 	Match larger larger
# I :: i ::
# 	/// i i
# 	Match i i
# can :: can ::
# 	/// can can
# 	Match can can
# reach :: reach ::
# 	/// reach reach
# 	Match reach reach
# the :: the ::
# 	/// the the
# 	Match the the
# key :: key ::
# 	/// key key
# 	Match key key
# and :: and ::
# 	/// and and
# 	Match and and
# if :: if ::
# 	/// if if
# 	Match if if
# it :: it ::
# 	/// it it
# 	Match it it
# makes :: makes ::
# 	/// makes makes
# 	Match makes makes
# me :: me ::
# 	/// me me
# 	Match me me
# grow :: grow ::
# 	/// grow grow
# 	Match grow grow
# smaller :: smaller ::
# 	/// smaller smaller
# 	Match smaller smaller
# I :: i ::
# 	/// i i
# 	Match i i
# can :: can ::
# 	/// can can
# 	Match can can
# creep :: creep ::
# 	/// creep creep
# 	Match creep creep
# under :: under ::
# 	/// under under
# 	Match under under
# the :: the ::
# 	/// the the
# 	Match the the
# door :: door ::
# 	/// door door
# 	Match door door
# so :: so ::
# 	/// so so
# 	Match so so
# either :: either ::
# 	/// either either
# 	Match either either
# way :: way ::
# 	/// way way
# 	Match way way
# I :: i ::
# 	/// ill i
# 	Match i ill
# ll :: ll ::
# 	/// ll ll
# 	Match ll ll
# get :: get ::
# 	/// get get
# 	Match get get
# into :: into ::
# 	/// into into
# 	Match into into
# the :: the ::
# 	/// the the
# 	Match the the
# garden :: garden ::
# 	/// garden garden
# 	Match garden garden
# and :: and ::
# 	/// and and
# 	Match and and
# I :: i ::
# 	/// i i
# 	Match i i
# do :: do ::
# 	/// dont do
# 	Match do dont
# care :: care ::
# 	/// nt care
# 	// care
# 	Match care care
# which :: which ::
# 	/// which which
# 	Match which which
# happens :: happens ::
# 	/// happens happens
# 	Match happens happens
# She :: she ::
# 	/// she she
# 	Match she she
# ate :: ate ::
# 	/// ate ate
# 	Match ate ate
# a :: a ::
# 	/// a a
# 	Match a a
# little :: little ::
# 	/// little little
# 	Match little little
# bit :: bit ::
# 	/// bit bit
# 	Match bit bit
# and :: and ::
# 	/// and and
# 	Match and and
# said :: said ::
# 	/// said said
# 	Match said said
# anxiously :: anxiously ::
# 	/// anxiously anxiously
# 	Match anxiously anxiously
# to :: to ::
# 	/// to to
# 	Match to to
# herself :: herself ::
# 	/// herself herself
# 	Match herself herself
# Which :: which ::
# 	/// which which
# 	Match which which
# way :: way ::
# 	/// way way
# 	Match way way
# Which :: which ::
# 	/// which which
# 	Match which which
# way :: way ::
# 	/// way way
# 	Match way way
# holding :: holding ::
# 	/// holding holding
# 	Match holding holding
# her :: her ::
# 	/// her her
# 	Match her her
# hand :: hand ::
# 	/// hand hand
# 	Match hand hand
# on :: on ::
# 	/// on on
# 	Match on on
# the :: the ::
# 	/// the the
# 	Match the the
# top :: top ::
# 	/// top top
# 	Match top top
# of :: of ::
# 	/// of of
# 	Match of of
# her :: her ::
# 	/// her her
# 	Match her her
# head :: head ::
# 	/// head head
# 	Match head head
# to :: to ::
# 	/// to to
# 	Match to to
# feel :: feel ::
# 	/// feel feel
# 	Match feel feel
# which :: which ::
# 	/// which which
# 	Match which which
# way :: way ::
# 	/// way way
# 	Match way way
# it :: it ::
# 	/// it it
# 	Match it it
# was :: was ::
# 	/// was was
# 	Match was was
# growing :: growing ::
# 	/// growing growing
# 	Match growing growing
# and :: and ::
# 	/// and and
# 	Match and and
# she :: she ::
# 	/// she she
# 	Match she she
# was :: was ::
# 	/// was was
# 	Match was was
# quite :: quite ::
# 	/// quite quite
# 	Match quite quite
# surprised :: surprised ::
# 	/// surprised surprised
# 	Match surprised surprised
# to :: to ::
# 	/// to to
# 	Match to to
# find :: find ::
# 	/// find find
# 	Match find find
# that :: that ::
# 	/// that that
# 	Match that that
# she :: she ::
# 	/// she she
# 	Match she she
# remained :: remained ::
# 	/// remained remained
# 	Match remained remained
# the :: the ::
# 	/// the the
# 	Match the the
# same :: same ::
# 	/// same same
# 	Match same same
# size :: size ::
# 	/// size size
# 	Match size size
# to :: to ::
# 	/// to to
# 	Match to to
# be :: be ::
# 	/// be be
# 	Match be be
# sure :: sure ::
# 	/// sure sure
# 	Match sure sure
# this :: this ::
# 	/// this this
# 	Match this this
# generally :: generally ::
# 	/// generally generally
# 	Match generally generally
# happens :: happens ::
# 	/// happens happens
# 	Match happens happens
# when :: when ::
# 	/// when when
# 	Match when when
# one :: one ::
# 	/// one one
# 	Match one one
# eats :: eats ::
# 	/// eats eats
# 	Match eats eats
# cake :: cake ::
# 	/// cake cake
# 	Match cake cake

# %%
stim_df.tok_pos.map(dict(enumerate(tokens_flat)))
# Out:
# 0           Alice
# 1             was
# 2       beginning
# 3              to
# 4             get
#           ...
# 2124      happens
# 2125         when
# 2126          one
# 2127         eats
# 2128        cake,
# Name: tok_pos, Length: 2129, dtype: object

# %%
stim_df.tail()
# Out:
#          Word  Segment      onset     offset  Order  LogFreq  LogFreq_Prev  \
# 2124  happens       12  45.226353  45.672448   2146    10.77         10.82
# 2125     when       12  45.677924  45.891353   2147    13.76         10.77
# 2126      one       12  45.896829  46.058972   2148    14.17         13.76
# 2127     eats       12  46.064448  46.322373   2149     8.15         14.17
# 2128     cake       12  46.327849  46.681557   2150     8.74          8.15
#
#       LogFreq_Next  SndPower    Length  Position  Sentence  IsLexical  \
# 2124         13.76  0.000708  0.446095         6        84        1.0
# 2125         14.17  0.003221  0.213429         7        84        0.0
# 2126          8.15  0.001984  0.162143         8        84        1.0
# 2127          8.74  0.000025  0.257925         9        84        1.0
# 2128          0.00  0.000005  0.353708        10        84        1.0
#
#          NGRAM       RNN       CFG  tok_pos
# 2124  5.574428  6.356812  2.969568     2100
# 2125  4.059164  6.720639  4.930669     2101
# 2126  1.380381  2.187682  0.725398     2102
# 2127  3.171368  3.941021  2.767965     2103
# 2128  5.386008  5.832085  3.692958     2104
