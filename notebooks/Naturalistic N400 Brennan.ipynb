# %% [markdown]
# This notebook uses our own EEG library to reproduce the N400 effect in the naturalistic dataset of Brennan et al. 2018.

# %%
import logging
logging.basicConfig(level=logging.DEBUG, handlers=[])
from pathlib import Path

import mne
mne.set_log_level(logging.WARNING)
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

basedir = Path("..").resolve()
import sys
sys.path.append(str(basedir))

DATA_DIR = Path("/om/data/public/language-eeg/brennan2018-v2")

FILTER_WINDOW = (0.5, 20)

EPOCH_WINDOW = (-0.1, 0.924)
TEST_WINDOW = (0.3, 0.5)
BASELINE_WINDOW = (None, 0)

# TODO: What is right for this montage?
# N400_ELECTRODES = ["1", "14", "24", "25", "26", "29", "30", "31", "41", "42", "44", "45"]
# Picking some central anterior sensors here
N400_ELECTRODES = ["45", "34", "35", "1"]

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from mfn400.adapters.brennan2018 import BrennanDatasetAdapter

# %%
data = BrennanDatasetAdapter(DATA_DIR)
# Out:
# loading subject data:   0%|          | 0/33 [00:00<?, ?it/s]
# 2022-05-19 12:04:25 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 1
# 2022-05-19 12:04:27 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 3
# 2022-05-19 12:04:30 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 4
# 2022-05-19 12:04:32 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 5
# 2022-05-19 12:04:35 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 6
# 2022-05-19 12:04:37 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 8
# 2022-05-19 12:04:39 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 10
# 2022-05-19 12:04:42 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 11
# 2022-05-19 12:04:44 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 12
# 2022-05-19 12:04:46 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 13
# 2022-05-19 12:04:49 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 14
# 2022-05-19 12:04:51 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 15
# 2022-05-19 12:04:53 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 16
# 2022-05-19 12:04:56 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 17
# 2022-05-19 12:04:58 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 18
# 2022-05-19 12:05:00 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 19
# 2022-05-19 12:05:03 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 20
# 2022-05-19 12:05:05 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 21
# 2022-05-19 12:05:07 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 22
# 2022-05-19 12:05:10 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 25
# 2022-05-19 12:05:12 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 26
# 2022-05-19 12:05:15 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 34
# 2022-05-19 12:05:17 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 35
# 2022-05-19 12:05:19 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 36
# 2022-05-19 12:05:22 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 37
# 2022-05-19 12:05:24 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 38
# 2022-05-19 12:05:26 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 39
# 2022-05-19 12:05:29 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 40
# 2022-05-19 12:05:31 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 41
# 2022-05-19 12:05:33 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 42
# 2022-05-19 12:05:35 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 44
# 2022-05-19 12:05:38 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 45
# 2022-05-19 12:05:40 | DEBUG    | mfn400.adapters.brennan2018 | Loading subject 48

# %%
erp_df = data.to_erp(EPOCH_WINDOW, TEST_WINDOW, BASELINE_WINDOW, apply_baseline=False,
                     filter_window=FILTER_WINDOW)
# Out:
# to_epochs:   0%|          | 0/33 [00:00<?, ?it/s]
# 2022-05-19 12:11:34 | DEBUG    | mfn400.adapters | to_epochs for subject 1
# 2022-05-19 12:11:35 | DEBUG    | mfn400.adapters | to_epochs for subject 3
# 2022-05-19 12:11:35 | DEBUG    | mfn400.adapters | to_epochs for subject 4
# 2022-05-19 12:11:36 | DEBUG    | mfn400.adapters | to_epochs for subject 5
# 2022-05-19 12:11:36 | DEBUG    | mfn400.adapters | to_epochs for subject 6
# 2022-05-19 12:11:37 | DEBUG    | mfn400.adapters | to_epochs for subject 8
# 2022-05-19 12:11:38 | DEBUG    | mfn400.adapters | to_epochs for subject 10
# 2022-05-19 12:11:38 | DEBUG    | mfn400.adapters | to_epochs for subject 11
# 2022-05-19 12:11:39 | DEBUG    | mfn400.adapters | to_epochs for subject 12
# 2022-05-19 12:11:39 | DEBUG    | mfn400.adapters | to_epochs for subject 13
# 2022-05-19 12:11:40 | DEBUG    | mfn400.adapters | to_epochs for subject 14
# 2022-05-19 12:11:41 | DEBUG    | mfn400.adapters | to_epochs for subject 15
# 2022-05-19 12:11:41 | DEBUG    | mfn400.adapters | to_epochs for subject 16
# 2022-05-19 12:11:42 | DEBUG    | mfn400.adapters | to_epochs for subject 17
# 2022-05-19 12:11:42 | DEBUG    | mfn400.adapters | to_epochs for subject 18
# 2022-05-19 12:11:43 | DEBUG    | mfn400.adapters | to_epochs for subject 19
# 2022-05-19 12:11:44 | DEBUG    | mfn400.adapters | to_epochs for subject 20
# 2022-05-19 12:11:44 | DEBUG    | mfn400.adapters | to_epochs for subject 21
# 2022-05-19 12:11:45 | DEBUG    | mfn400.adapters | to_epochs for subject 22
# 2022-05-19 12:11:45 | DEBUG    | mfn400.adapters | to_epochs for subject 25
# 2022-05-19 12:11:46 | DEBUG    | mfn400.adapters | to_epochs for subject 26
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 erp_df = data.to_erp(EPOCH_WINDOW, TEST_WINDOW, BASELINE_WINDOW, apply_baseline=False,
#       2                      filter_window=FILTER_WINDOW)
#
# File /net/vast-storage.ib.cluster/scratch/vast/cpl/jgauthie/scratch/broderick2018/mfn400/adapters/__init__.py:165, in MNEDatasetAdapter.to_erp(self, epoch_window, test_window, baseline_window, apply_baseline, **preprocessing_kwargs)
#     162 # If we are not applying baseline, ask MNE to epoch without awareness
#     163 # of baseline.
#     164 epoch_baseline = baseline_window if apply_baseline else None
# --> 165 epochs = self.to_epochs(epoch_window, epoch_baseline,
#     166                         **preprocessing_kwargs)
#     167 return pd.concat(
#     168     [prepare_erp_df(epochs[subject],
#     169                     self.get_presentation_data(subject),
#    (...)
#     176     keys=[int(idx) for idx in epochs.keys()]
#     177 )
#
# File /net/vast-storage.ib.cluster/scratch/vast/cpl/jgauthie/scratch/broderick2018/mfn400/adapters/__init__.py:136, in MNEDatasetAdapter.to_epochs(self, epoch_window, baseline, **preprocessing_kwargs)
#     133 if not self.preprocessed:
#     134     self.run_preprocessing(**preprocessing_kwargs)
# --> 136 epochs = {
#     137     subject_id: self._to_epochs_single_subject(
#     138         subject_id, epoch_window, baseline=baseline,
#     139         **preprocessing_kwargs)
#     140     for subject_id in tqdm(self._raw_data, desc="to_epochs")
#     141 }
#     142 return epochs
#
# File /net/vast-storage.ib.cluster/scratch/vast/cpl/jgauthie/scratch/broderick2018/mfn400/adapters/__init__.py:137, in <dictcomp>(.0)
#     133 if not self.preprocessed:
#     134     self.run_preprocessing(**preprocessing_kwargs)
#     136 epochs = {
# --> 137     subject_id: self._to_epochs_single_subject(
#     138         subject_id, epoch_window, baseline=baseline,
#     139         **preprocessing_kwargs)
#     140     for subject_id in tqdm(self._raw_data, desc="to_epochs")
#     141 }
#     142 return epochs
#
# File /net/vast-storage.ib.cluster/scratch/vast/cpl/jgauthie/scratch/broderick2018/mfn400/adapters/__init__.py:121, in MNEDatasetAdapter._to_epochs_single_subject(self, subject_id, epoch_window, baseline, **preprocessing_kwargs)
#     118 events, event_id = mne.events_from_annotations(raw, verbose=False)
#     120 epoch_tmin, epoch_tmax = epoch_window
# --> 121 return mne.Epochs(raw, events=events, event_id=event_id,
#     122                   tmin=epoch_tmin, tmax=epoch_tmax,
#     123                   reject_by_annotation=False,
#     124                   preload=True, baseline=baseline,
#     125                   verbose=False)
#
# File <decorator-gen-255>:10, in __init__(self, raw, events, event_id, tmin, tmax, baseline, picks, preload, reject, flat, proj, decim, reject_tmin, reject_tmax, detrend, on_missing, reject_by_annotation, metadata, event_repeated, verbose)
#
# File /opt/conda/lib/python3.9/site-packages/mne/epochs.py:2650, in Epochs.__init__(self, raw, events, event_id, tmin, tmax, baseline, picks, preload, reject, flat, proj, decim, reject_tmin, reject_tmax, detrend, on_missing, reject_by_annotation, metadata, event_repeated, verbose)
#    2647 raw_sfreq = raw.info['sfreq']
#    2649 # call BaseEpochs constructor
# -> 2650 super(Epochs, self).__init__(
#    2651     info, None, events, event_id, tmin, tmax,
#    2652     metadata=metadata, baseline=baseline, raw=raw, picks=picks,
#    2653     reject=reject, flat=flat, decim=decim, reject_tmin=reject_tmin,
#    2654     reject_tmax=reject_tmax, detrend=detrend,
#    2655     proj=proj, on_missing=on_missing, preload_at_end=preload,
#    2656     event_repeated=event_repeated, verbose=verbose,
#    2657     raw_sfreq=raw_sfreq, annotations=raw.annotations)
#
# File <decorator-gen-242>:10, in __init__(self, info, data, events, event_id, tmin, tmax, baseline, raw, picks, reject, flat, decim, reject_tmin, reject_tmax, detrend, proj, on_missing, preload_at_end, selection, drop_log, filename, metadata, event_repeated, verbose, raw_sfreq, annotations)
#
# File /opt/conda/lib/python3.9/site-packages/mne/epochs.py:455, in BaseEpochs.__init__(***failed resolving arguments***)
#     450     self.drop_log = drop_log
#     452 self.events = self.events[selected]
#     454 self.events, self.event_id, self.selection, self.drop_log = \
# --> 455     _handle_event_repeated(
#     456         self.events, self.event_id, event_repeated,
#     457         self.selection, self.drop_log)
#     459 # then subselect
#     460 sub = np.where(np.in1d(selection, self.selection))[0]
#
# File /opt/conda/lib/python3.9/site-packages/mne/epochs.py:310, in _handle_event_repeated(events, event_id, event_repeated, selection, drop_log)
#     308 drop_log = list(drop_log)
#     309 if event_repeated == 'error':
# --> 310     raise RuntimeError('Event time samples were not unique. Consider '
#     311                        'setting the `event_repeated` parameter."')
#     313 elif event_repeated == 'drop':
#     314     logger.info('Multiple event values for single event times found. '
#     315                 'Keeping the first occurrence and dropping all others.')
#
# RuntimeError: Event time samples were not unique. Consider setting the `event_repeated` parameter."

# %%
erp_df
# Out:
#                    segment_idx  sentence_idx  word_idx       Word       onset  \
# subject_idx index
# 1           0                1             1         1      Alice    3.772000
#             1                1             1         2        was    4.288721
#             2                1             1         3  beginning    4.510543
#             3                1             1         4         to    4.982929
#             4                1             1         5        get    5.078925
# ...                        ...           ...       ...        ...         ...
# 13          2124            12            84         6    happens  730.972874
#             2125            12            84         7       when  731.424445
#             2126            12            84         8        one  731.643350
#             2127            12            84         9       eats  731.810969
#             2128            12            84        10       cake  732.074370
#
#                        offset  Order  LogFreq      SndPower    Length  ...  \
# subject_idx index                                                      ...
# 1           0        4.334721      1     8.65  3.621500e-07  0.562721  ...
#             1        4.556543      2    14.56  3.843500e-09  0.267822  ...
#             2        5.028929      3    10.69  3.686500e-09  0.518386  ...
#             3        5.124925      4    16.35  3.969700e-09  0.141996  ...
#             4        5.388327      5    13.79  3.774700e-09  0.309402  ...
# ...                       ...    ...      ...           ...       ...  ...
# 13          2124   731.418969   2146    10.77  7.081200e-04  0.446095  ...
#             2125   731.637874   2147    13.76  3.221100e-03  0.213429  ...
#             2126   731.805493   2148    14.17  1.984200e-03  0.162143  ...
#             2127   732.068894   2149     8.15  2.473000e-05  0.257925  ...
#             2128   732.428078   2150     8.74  5.423800e-06  0.353708  ...
#
#                    57_baseline  58_baseline  59_baseline  60_baseline  \
# subject_idx index
# 1           0        -1.475362     1.018221     3.639740     9.178524
#             1        -2.079682    -7.315422    -9.789070   -12.821799
#             2        -1.403047    -2.836003    -1.997360     2.239624
#             3        -2.823259    -0.355007     2.651694     1.328021
#             4         1.697060     0.866455     2.703942     3.773767
# ...                        ...          ...          ...          ...
# 13          2124      0.240526    -3.088103    -7.457530    -9.936517
#             2125     -1.578495     0.703140     2.958282     0.676569
#             2126      7.339651    14.289617    18.462127    21.911430
#             2127     -2.539556    -1.303939    -3.380252    -4.360008
#             2128     -2.471963    -2.827446    -2.255271    -3.980100
#
#                   61_baseline  VEOG_baseline  Aux5_baseline  29_baseline  \
# subject_idx index
# 1           0       11.813051   2.225084e+06   58973.355255    -1.739714
#             1      -13.976495   2.277766e+06  317729.892392    -1.710223
#             2        3.279069   2.278773e+06  264685.650813    -0.460853
#             3        0.341111   2.285470e+06  810552.359796    -1.014870
#             4        5.006329   2.282099e+06  503885.421098    -0.910472
# ...                       ...            ...            ...          ...
# 13          2124   -13.762729   7.868602e+05            NaN    -0.549972
#             2125    -2.112208   7.902282e+05            NaN     0.731157
#             2126    22.538949   7.906945e+05            NaN     2.550683
#             2127    -1.458582   7.907120e+05            NaN    -0.879637
#             2128    -4.203327   7.902796e+05            NaN    -0.800961
#
#                         AUD  AUD_baseline
# subject_idx index
# 1           0           NaN           NaN
#             1           NaN           NaN
#             2           NaN           NaN
#             3           NaN           NaN
#             4           NaN           NaN
# ...                     ...           ...
# 13          2124   0.038277  66069.773672
#             2125   0.063910  40047.566133
#             2126   0.018782  53636.747467
#             2127   0.046487  58484.182657
#             2128   0.007058  24534.779491
#
# [21290 rows x 144 columns]

# %%
our_erp_df = erp_df.copy()
# Average over N400 electrodes as given in paper.
n400_electrodes = set(N400_ELECTRODES) & set(our_erp_df.columns)
our_erp_df = our_erp_df.reset_index().set_index(["subject_idx", "sentence_idx", "word_idx"]) \
    .loc[:, n400_electrodes].mean(axis=1).rename("n400")
our_erp_df = pd.DataFrame(our_erp_df)
our_erp_df
# Out:
#                                         n400
# subject_idx sentence_idx word_idx
# 1           1            1          0.995938
#                          2        -10.070998
#                          3          1.359659
#                          4          9.355550
#                          5          5.557713
# ...                                      ...
# 13          84           6         -1.626823
#                          7         -6.467515
#                          8         -1.872713
#                          9          4.472840
#                          10       -10.576467
#
# [21290 rows x 1 columns]

# %%
our_baseline_df = erp_df.reset_index().set_index(["subject_idx", "sentence_idx", "word_idx"]) \
    .loc[:, [f"{el}_baseline" for el in n400_electrodes]].mean(axis=1).rename("our_baseline")
our_baseline_df
# Out:
# subject_idx  sentence_idx  word_idx
# 1            1             1           -0.135712
#                            2           -8.749145
#                            3            2.767415
#                            4            1.790051
#                            5            2.096851
#                                          ...
# 13           84            6           -5.934142
#                            7           -3.052708
#                            8           15.778101
#                            9            0.562239
#                            10          -3.441129
# Name: our_baseline, Length: 21290, dtype: float64

# %%
merged_df = pd.merge(erp_df.reset_index(), our_erp_df, 
                     left_on=["subject_idx", "sentence_idx", "word_idx"],
                     right_index=True)
merged_df = pd.merge(merged_df, our_baseline_df,
                     left_on=["subject_idx", "sentence_idx", "word_idx"],
                     right_index=True)
merged_df
# Out:
#        subject_idx  index  segment_idx  sentence_idx  word_idx       Word  \
# 0                1      0            1             1         1      Alice
# 1                1      1            1             1         2        was
# 2                1      2            1             1         3  beginning
# 3                1      3            1             1         4         to
# 4                1      4            1             1         5        get
# ...            ...    ...          ...           ...       ...        ...
# 21285           13   2124           12            84         6    happens
# 21286           13   2125           12            84         7       when
# 21287           13   2126           12            84         8        one
# 21288           13   2127           12            84         9       eats
# 21289           13   2128           12            84        10       cake
#
#             onset      offset  Order  LogFreq  ...  59_baseline  60_baseline  \
# 0        3.772000    4.334721      1     8.65  ...     3.639740     9.178524
# 1        4.288721    4.556543      2    14.56  ...    -9.789070   -12.821799
# 2        4.510543    5.028929      3    10.69  ...    -1.997360     2.239624
# 3        4.982929    5.124925      4    16.35  ...     2.651694     1.328021
# 4        5.078925    5.388327      5    13.79  ...     2.703942     3.773767
# ...           ...         ...    ...      ...  ...          ...          ...
# 21285  730.972874  731.418969   2146    10.77  ...    -7.457530    -9.936517
# 21286  731.424445  731.637874   2147    13.76  ...     2.958282     0.676569
# 21287  731.643350  731.805493   2148    14.17  ...    18.462127    21.911430
# 21288  731.810969  732.068894   2149     8.15  ...    -3.380252    -4.360008
# 21289  732.074370  732.428078   2150     8.74  ...    -2.255271    -3.980100
#
#        61_baseline  VEOG_baseline  Aux5_baseline  29_baseline       AUD  \
# 0        11.813051   2.225084e+06   58973.355255    -1.739714       NaN
# 1       -13.976495   2.277766e+06  317729.892392    -1.710223       NaN
# 2         3.279069   2.278773e+06  264685.650813    -0.460853       NaN
# 3         0.341111   2.285470e+06  810552.359796    -1.014870       NaN
# 4         5.006329   2.282099e+06  503885.421098    -0.910472       NaN
# ...            ...            ...            ...          ...       ...
# 21285   -13.762729   7.868602e+05            NaN    -0.549972  0.038277
# 21286    -2.112208   7.902282e+05            NaN     0.731157  0.063910
# 21287    22.538949   7.906945e+05            NaN     2.550683  0.018782
# 21288    -1.458582   7.907120e+05            NaN    -0.879637  0.046487
# 21289    -4.203327   7.902796e+05            NaN    -0.800961  0.007058
#
#        AUD_baseline       n400  our_baseline
# 0               NaN   0.995938     -0.135712
# 1               NaN -10.070998     -8.749145
# 2               NaN   1.359659      2.767415
# 3               NaN   9.355550      1.790051
# 4               NaN   5.557713      2.096851
# ...             ...        ...           ...
# 21285  66069.773672  -1.626823     -5.934142
# 21286  40047.566133  -6.467515     -3.052708
# 21287  53636.747467  -1.872713     15.778101
# 21288  58484.182657   4.472840      0.562239
# 21289  24534.779491 -10.576467     -3.441129
#
# [21290 rows x 148 columns]

# %%
merged_df.to_csv("brennan_erp_n400.csv")

# %% [markdown]
# ---

# %%
merged_df.our_baseline / 1e3
# Out:
# 0      -2.645913
# 1      -2.654308
# 2      -2.653121
# 3      -2.657983
# 4      -2.662320
#           ...
# 8511    1.174708
# 8512    1.170416
# 8513    1.172266
# 8514    1.170332
# 8515    1.172322
# Name: our_baseline, Length: 8516, dtype: float64
